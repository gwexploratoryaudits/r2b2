# %%
import pandas as pd

fname = 'Virginia_Elections_Database__2016_President_General_Election_including_precincts.csv'
df = pd.read_csv(fname)
df
# Out:
#           County/City Ward                             Pct Hillary R. Clinton  \
# 0                 NaN  NaN                             NaN         Democratic
# 1     Accomack County    -              101 - Chincoteague                444
# 2     Accomack County    -                  201 - Atlantic                175
# 3     Accomack County    -            202 - Greenbackville                302
# 4     Accomack County    -                301 - New Church                713
# ...               ...  ...                             ...                ...
# 2745      York County    -                      501 - Tabb                955
# 2746      York County    -                    502 - Bethel              1,184
# 2747      York County    -  Ab - Central Absentee Precinct              1,657
# 2748      York County    -                     Provisional                 10
# 2749           TOTALS  NaN                             NaN          1,981,473
#
#      Donald J. Trump Gary Johnson Evan McMullin Jill Stein All Others  \
# 0         Republican  Libertarian   Independent      Green        NaN
# 1              1,188           26            10          7          5
# 2                553           13             7          1          1
# 3                697           17             4          7          3
# 4                592           21             4          3          5
# ...              ...          ...           ...        ...        ...
# 2745           1,705           91            48         16         24
# 2746           1,496          106            51         21         32
# 2747           1,712          150            71         16         38
# 2748              14            2             0          1          1
# 2749       1,769,443      118,274        54,054     27,638     33,749
#
#      Total Votes Cast
# 0                 NaN
# 1               1,680
# 2                 750
# 3               1,030
# 4               1,338
# ...               ...
# 2745            2,839
# 2746            2,890
# 2747            3,644
# 2748               28
# 2749        3,984,631
#
# [2750 rows x 10 columns]

# %%
# create a dictionary containing a list of all ballots
# where each ballot has id number 1...N, candidate, and precinct
cands = ['Hillary R. Clinton', 'Donald J. Trump', 'Gary Johnson', 'Evan McMullin', 'Jill Stein', 'All Others']
bals = {"bals": []}

index = 0
for precIndex in range(1,2749):
    precinctRow = df.iloc[precIndex]
    for cand in cands:
        votesForCand = int(precinctRow[cand].replace(',', ''))
        for i in range(votesForCand):
            bals["bals"].append({
                'id': index,
                'precinct': precinctRow['Pct'],
                'candidate': cand
            })
            index += 1

# %%
# check things
print('total num ballots is ' + str(len(bals["bals"]))+ ' and should be 3984631')

num = 1123412
print('ballot '+str(bals["bals"][num]['id'])+' should be num '+str(num))
# Out:
# total num ballots is 3984631 and should be 3984631
# ballot 1123412 should be num 1123412

# %%
# save the bals in a json file 
import json
with open('bals.json','w') as f:
    json.dump(bals, f)
