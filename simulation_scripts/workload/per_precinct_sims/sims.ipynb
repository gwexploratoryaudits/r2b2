# %%
import pandas as pd

fname = 'Virginia_Elections_Database__2016_President_General_Election_including_precincts.csv'
df = pd.read_csv(fname)
df
# Out:
#           County/City Ward                             Pct Hillary R. Clinton  \
# 0                 NaN  NaN                             NaN         Democratic
# 1     Accomack County    -              101 - Chincoteague                444
# 2     Accomack County    -                  201 - Atlantic                175
# 3     Accomack County    -            202 - Greenbackville                302
# 4     Accomack County    -                301 - New Church                713
# ...               ...  ...                             ...                ...
# 2745      York County    -                      501 - Tabb                955
# 2746      York County    -                    502 - Bethel              1,184
# 2747      York County    -  Ab - Central Absentee Precinct              1,657
# 2748      York County    -                     Provisional                 10
# 2749           TOTALS  NaN                             NaN          1,981,473
#
#      Donald J. Trump Gary Johnson Evan McMullin Jill Stein All Others  \
# 0         Republican  Libertarian   Independent      Green        NaN
# 1              1,188           26            10          7          5
# 2                553           13             7          1          1
# 3                697           17             4          7          3
# 4                592           21             4          3          5
# ...              ...          ...           ...        ...        ...
# 2745           1,705           91            48         16         24
# 2746           1,496          106            51         21         32
# 2747           1,712          150            71         16         38
# 2748              14            2             0          1          1
# 2749       1,769,443      118,274        54,054     27,638     33,749
#
#      Total Votes Cast
# 0                 NaN
# 1               1,680
# 2                 750
# 3               1,030
# 4               1,338
# ...               ...
# 2745            2,839
# 2746            2,890
# 2747            3,644
# 2748               28
# 2749        3,984,631
#
# [2750 rows x 10 columns]

# %%
# create a dictionary containing a list of all ballots
# where each ballot has id number 1...N, candidate, and precinct
from itertools import count


cands = ['Hillary R. Clinton', 'Donald J. Trump', 'Gary Johnson', 'Evan McMullin', 'Jill Stein', 'All Others']
bals = {"bals": []}
precinct_list = {"precinct_list": []}
county_list = {"county_list": []}
index = 0
county_and_precinct_info = {}
for precIndex in range(1,2749):
    precinctRow = df.iloc[precIndex]
    for cand in cands:
        votesForCand = int(precinctRow[cand].replace(',', ''))
        for i in range(votesForCand):
            bals["bals"].append({
                'id': index,
                'precinct': precinctRow['Pct'],
                'county': precinctRow['County/City'],
                'candidate': cand
            })
            county = precinctRow['County/City']
            if county not in county_and_precinct_info:
                county_and_precinct_info.update({county:[]})
            precinct = precinctRow['Pct']
            if precinct not in county_and_precinct_info[county]:
                county_and_precinct_info[county].append(precinct)
            precinct_list["precinct_list"].append(precinctRow['Pct'])
            county_list["county_list"].append(precinctRow['County/City'])
            index += 1
precinct_list["precinct_list"] = list(set(precinct_list["precinct_list"]))
county_list["county_list"] = list(set(county_list["county_list"]))

# %%
county_list
# Out:
# {'county_list': ['Fairfax City',
#   'Madison County',
#   'Accomack County',
#   'Hampton City',
#   'Goochland County',
#   'Lynchburg City',
#   'Mecklenburg County',
#   'Westmoreland County',
#   'Arlington County',
#   'Hanover County',
#   'Floyd County',
#   'James City County',
#   'Frederick County',
#   'Buena Vista City',
#   'Colonial Heights City',
#   'Northumberland County',
#   'Staunton City',
#   'Poquoson City',
#   'Pittsylvania County',
#   'Dinwiddie County',
#   'Shenandoah County',
#   'Augusta County',
#   'Portsmouth City',
#   'Grayson County',
#   'Craig County',
#   'Russell County',
#   'Norton City',
#   'Rockbridge County',
#   'Warren County',
#   'Giles County',
#   'Brunswick County',
#   'Carroll County',
#   'Northampton County',
#   'Lee County',
#   'Wythe County',
#   'Amelia County',
#   'Montgomery County',
#   'Martinsville City',
#   'Albemarle County',
#   'Richmond County',
#   'Gloucester County',
#   'Fauquier County',
#   'Nottoway County',
#   'Salem City',
#   'Charlottesville City',
#   'Louisa County',
#   'Norfolk City',
#   'Patrick County',
#   'Prince George County',
#   'Suffolk City',
#   'Lancaster County',
#   'Waynesboro City',
#   'King George County',
#   'Galax City',
#   'Loudoun County',
#   'Scott County',
#   'Manassas Park City',
#   'Amherst County',
#   'Henry County',
#   'Bath County',
#   'Pulaski County',
#   'Buchanan County',
#   'Roanoke County',
#   'Roanoke City',
#   'Fredericksburg City',
#   'Alexandria City',
#   'Appomattox County',
#   'Rockingham County',
#   'Bland County',
#   'Charlotte County',
#   'Culpeper County',
#   'Franklin County',
#   'Harrisonburg City',
#   'Powhatan County',
#   'Spotsylvania County',
#   'Danville City',
#   'York County',
#   'Halifax County',
#   'Fairfax County',
#   'King William County',
#   'Chesapeake City',
#   'Lexington City',
#   'Newport News City',
#   'Petersburg City',
#   'Washington County',
#   'Winchester City',
#   'Bristol City',
#   'Falls Church City',
#   'Nelson County',
#   'New Kent County',
#   'Charles City County',
#   'Radford City',
#   'Essex County',
#   'Prince William County',
#   'Fluvanna County',
#   'Surry County',
#   'Smyth County',
#   'Wise County',
#   'Manassas City',
#   'Williamsburg City',
#   'Richmond City',
#   'Alleghany County',
#   'Greensville County',
#   'Greene County',
#   'Isle of Wight County',
#   'Cumberland County',
#   'Campbell County',
#   'Caroline County',
#   'Middlesex County',
#   'Chesterfield County',
#   'Covington City',
#   'Hopewell City',
#   'Lunenburg County',
#   'Dickenson County',
#   'Tazewell County',
#   'Bedford County',
#   'Page County',
#   'Southampton County',
#   'Sussex County',
#   'Stafford County',
#   'Botetourt County',
#   'Buckingham County',
#   'Clarke County',
#   'Prince Edward County',
#   'Mathews County',
#   'King and Queen County',
#   'Emporia City',
#   'Virginia Beach City',
#   'Henrico County',
#   'Franklin City',
#   'Orange County',
#   'Highland County',
#   'Rappahannock County']}

# %%
per_county_votes = {}
for county in county_list["county_list"]:
    per_county_votes.update({county:0})
for precIndex in range(1,2749):
    precinctRow = df.iloc[precIndex]
    per_county_votes[precinctRow['County/City']] += int(precinctRow['Total Votes Cast'].replace(',', ''))

# %%
per_county_votes
dict(sorted(per_county_votes.items(), reverse=True, key=lambda item: item[1]))
# Out:
# {'Fairfax County': 551183,
#  'Virginia Beach City': 203262,
#  'Prince William County': 196538,
#  'Loudoun County': 183097,
#  'Chesterfield County': 176461,
#  'Henrico County': 163654,
#  'Arlington County': 121356,
#  'Chesapeake City': 112705,
#  'Richmond City': 103484,
#  'Norfolk City': 83388,
#  'Alexandria City': 75770,
#  'Newport News City': 75715,
#  'Stafford County': 65934,
#  'Hanover County': 62753,
#  'Spotsylvania County': 62562,
#  'Hampton City': 62356,
#  'Albemarle County': 56726,
#  'Roanoke County': 51489,
#  'Portsmouth City': 43265,
#  'Suffolk City': 43240,
#  'James City County': 43173,
#  'Montgomery County': 43031,
#  'Bedford County': 42525,
#  'Frederick County': 40440,
#  'Roanoke City': 39466,
#  'Rockingham County': 37487,
#  'Fauquier County': 37467,
#  'Augusta County': 36343,
#  'Lynchburg City': 35671,
#  'York County': 34118,
#  'Pittsylvania County': 31598,
#  'Campbell County': 27535,
#  'Franklin County': 26971,
#  'Washington County': 25847,
#  'Henry County': 24106,
#  'Charlottesville City': 22472,
#  'Culpeper County': 22218,
#  'Isle of Wight County': 21075,
#  'Shenandoah County': 20513,
#  'Gloucester County': 19619,
#  'Danville City': 18952,
#  'Botetourt County': 18739,
#  'Tazewell County': 18566,
#  'Harrisonburg City': 17993,
#  'Warren County': 17960,
#  'Louisa County': 17631,
#  'Orange County': 17270,
#  'Halifax County': 17001,
#  'Powhatan County': 16900,
#  'Prince George County': 16184,
#  'Accomack County': 15818,
#  'Manassas City': 15411,
#  'Amherst County': 15396,
#  'Pulaski County': 15167,
#  'Wise County': 15163,
#  'Mecklenburg County': 14945,
#  'Caroline County': 14863,
#  'Goochland County': 14037,
#  'Petersburg City': 13786,
#  'Carroll County': 13668,
#  'Fluvanna County': 13597,
#  'Dinwiddie County': 13575,
#  'Wythe County': 13343,
#  'Smyth County': 12890,
#  'Russell County': 12246,
#  'New Kent County': 12242,
#  'Salem City': 12225,
#  'King George County': 12059,
#  'Fairfax City': 12030,
#  'Fredericksburg City': 11264,
#  'Staunton City': 11255,
#  'Rockbridge County': 10795,
#  'Page County': 10740,
#  'Winchester City': 10667,
#  'Scott County': 10100,
#  'Greene County': 9608,
#  'Lee County': 9399,
#  'Buchanan County': 9247,
#  'Waynesboro City': 9204,
#  'King William County': 9161,
#  'Prince Edward County': 9143,
#  'Hopewell City': 9008,
#  'Southampton County': 8878,
#  'Westmoreland County': 8574,
#  'Patrick County': 8525,
#  'Colonial Heights City': 8457,
#  'Nelson County': 8318,
#  'Clarke County': 8213,
#  'Giles County': 8212,
#  'Floyd County': 8051,
#  'Appomattox County': 8011,
#  'Falls Church City': 7757,
#  'Brunswick County': 7669,
#  'Williamsburg City': 7626,
#  'Northumberland County': 7398,
#  'Alleghany County': 7325,
#  'Buckingham County': 7295,
#  'Grayson County': 7285,
#  'Poquoson City': 7177,
#  'Amelia County': 7040,
#  'Bristol City': 7032,
#  'Madison County': 6979,
#  'Nottoway County': 6744,
#  'Lancaster County': 6645,
#  'Dickenson County': 6440,
#  'Northampton County': 6172,
#  'Radford City': 6085,
#  'Middlesex County': 6017,
#  'Martinsville City': 5907,
#  'Charlotte County': 5808,
#  'Lunenburg County': 5586,
#  'Essex County': 5408,
#  'Mathews County': 5311,
#  'Manassas Park City': 5232,
#  'Sussex County': 5044,
#  'Cumberland County': 4906,
#  'Rappahannock County': 4483,
#  'Greensville County': 4363,
#  'Surry County': 4228,
#  'Charles City County': 4107,
#  'Franklin City': 4070,
#  'King and Queen County': 3697,
#  'Richmond County': 3661,
#  'Bland County': 3139,
#  'Craig County': 2794,
#  'Lexington City': 2465,
#  'Buena Vista City': 2407,
#  'Covington City': 2382,
#  'Galax City': 2376,
#  'Emporia City': 2367,
#  'Bath County': 2253,
#  'Norton City': 1460,
#  'Highland County': 1391}

# %%
# check things
print('total num ballots is ' + str(len(bals["bals"]))+ ' and should be 3984631')

num = 1123412
print('ballot '+str(bals["bals"][num]['id'])+' should be num '+str(num))

print(len(precinct_list["precinct_list"]))
print(len(county_list["county_list"]))
# Out:
# total num ballots is 3984631 and should be 3984631
# ballot 1123412 should be num 1123412
# 2425
# 133

# %%
# save the bals in a json file 
import json
with open('bals.json','w') as f:
    json.dump(bals, f)
with open('precinct_list.json','w') as f:
    json.dump(precinct_list, f)
with open('county_list.json','w') as f:
    json.dump(county_list, f)
with open('county_and_precinct_info.json','w') as f:
    json.dump(county_and_precinct_info, f)

# %%
county_and_precinct_info
# Out:
# {'Accomack County': ['101 - Chincoteague',
#   '201 - Atlantic',
#   '202 - Greenbackville',
#   '301 - New Church',
#   '401 - Bloxom',
#   '402 - Parksley',
#   '403 - Saxis',
#   '501 - Mappsville',
#   '502 - Rue',
#   '601 - Accomac',
#   '602 - Tangier',
#   '701 - Nandua',
#   '801 - Bobtown',
#   '802 - Melfa',
#   '803 - Wachapreague',
#   '901 - Painter',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Albemarle County': ['101 - Woodbrook',
#   '103 - Branchlands',
#   '104 - Agnor-hurt',
#   '105 - Dunlora',
#   '106 - Northside',
#   '201 - Jack Jouett',
#   '202 - University Hall',
#   '203 - Georgetown',
#   '204 - Belfield',
#   '301 - Ivy',
#   '302 - Red Hill',
#   '304 - East Ivy',
#   '305 - Country Green',
#   '306 - Porters',
#   '307 - Yellow Mountain',
#   '401 - Scottsville',
#   '402 - Monticello',
#   '405 - Cale',
#   '406 - Stone Robinson',
#   '501 - Keswick',
#   '502 - Stony Point',
#   '503 - Hollymead',
#   '504 - Free Bridge',
#   '506 - Baker-butler',
#   '601 - Crozet',
#   '602 - Free Union',
#   '603 - Earlysville',
#   '604 - Brownsville',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Alexandria City': ['101 - Ladrey Senior Building',
#   '102 - City Hall',
#   '103 - Lyles Crouch School',
#   '104 - Durant Center',
#   '105 - Lee Center',
#   '106 - Cora Kelly Center',
#   '107 - Mt Vernon Recreation Center',
#   '108 - George Washington Middle Sch',
#   '109 - Fire Department Headquarters',
#   '110 - Charles Houston Center',
#   '201 - Maury School',
#   '202 - George Mason School',
#   '203 - Agudas Achim Synagogue',
#   '204 - Blessed Sacrament Church',
#   '205 - Douglas Macarthur School',
#   '206 - Chinquapin Park Recreation Ctr',
#   '207 - Temple Beth El Synagogue',
#   '208 - Nova Arts Center',
#   '209 - James K Polk School',
#   '210 - The Hermitage',
#   '302 - Patrick Henry Rec Center',
#   '303 - Charles E Beatley Library',
#   '304 - Samuel Tucker School',
#   '305 - John Adams School',
#   '306 - William Ramsay School',
#   '307 - South Port',
#   '308 - Cameron Station Community Ctr',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Alleghany County': ['101 - Arritt',
#   '103 - Dameron',
#   '201 - Humpback Bridge',
#   '202 - Dolly Ann',
#   '301 - Callaghan',
#   '302 - Griffith',
#   '401 - Low Moor',
#   '402 - Jackson Heights',
#   '501 - Iron Gate',
#   '502 - Peters Switch',
#   '601 - District 1',
#   '701 - District 2',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Amelia County': ['101 - Number One',
#   '201 - Number Two',
#   '301 - Number Three',
#   '401 - Number Four',
#   '501 - Number Five',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Amherst County': ['101 - Wright Shop',
#   '102 - New Glasgow',
#   '103 - Coolwell',
#   '201 - Court House',
#   '202 - Temperance',
#   '301 - Monroe',
#   '302 - Elon',
#   '303 - Pleasant View',
#   '401 - Amelon',
#   '402 - Lonco',
#   '501 - Madison',
#   'Ab - Central Absentee Precinct'],
#  'Appomattox County': ['101 - Vera',
#   '102 - Pamplin',
#   '201 - Chap',
#   '202 - Spout Spring',
#   '301 - Us 460',
#   '302 - Stonewall',
#   '401 - Courthouse',
#   '501 - Oakville',
#   '502 - Agee',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Arlington County': ['1 - Arlington',
#   '2 - Ashton Heights',
#   '3 - Aurora Hills',
#   '4 - Ballston',
#   '5 - Barcroft',
#   '6 - Crystal City',
#   '7 - Cherrydale',
#   '8 - Hume',
#   '9 - Columbia',
#   '10 - Wilson',
#   '11 - East Falls Church',
#   '12 - Fairlington',
#   '13 - Glen Carlyn',
#   '14 - Clarendon',
#   '15 - Lyon Park',
#   '16 - Lyon Village',
#   '17 - Overlee Knolls',
#   '18 - Park Lane',
#   '19 - Rosslyn',
#   '20 - Thrifton',
#   '21 - Virginia Highlands',
#   '22 - Abingdon',
#   '23 - Westover',
#   '24 - Woodlawn',
#   '25 - Arlington Forest',
#   '26 - Fillmore',
#   '27 - Jefferson',
#   '28 - Claremont',
#   '29 - Dominion Hills',
#   '30 - Glebe',
#   '31 - Lexington',
#   '32 - Oakridge',
#   '33 - Rock Spring',
#   '34 - Yorktown',
#   '35 - Madison',
#   '36 - Marshall',
#   '37 - Nottingham',
#   '38 - Arlington View',
#   '39 - Ashlawn',
#   '40 - Virginia Square',
#   '41 - Woodbury',
#   '42 - Shirlington',
#   '43 - Arlington Mill',
#   '44 - Dawson Terrace',
#   '45 - Buckingham',
#   '46 - Central',
#   '47 - Four Mile Run',
#   '48 - Courtlands',
#   '49 - Monroe',
#   '50 - Crystal Plaza',
#   '51 - Taylor',
#   '52 - Gunston',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Augusta County': ['101 - Jolivue',
#   '102 - Stuarts Draft Elementary',
#   '103 - Verona',
#   '201 - Crimora',
#   '202 - New Hope',
#   '203 - Weyers Cave',
#   '301 - Fort Defiance',
#   '302 - North River',
#   '303 - Mount Solon',
#   '304 - Churchville Fire Station',
#   '401 - Buffalo Gap',
#   '402 - Churchville Elementary',
#   '403 - Craigsville',
#   '404 - Deerfield',
#   '405 - Cedar Green',
#   '501 - Greenville',
#   '502 - Middlebrook',
#   '503 - Spottswood',
#   '504 - White Hill',
#   '601 - Sherando',
#   '602 - Ridgeview',
#   '603 - Lyndhurst',
#   '801 - Dooms',
#   '802 - Fishersville',
#   '803 - Wilson',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Bath County': ['101 - Warm Springs',
#   '102 - Mountain Grove',
#   '201 - Hot Springs',
#   '301 - Fairview',
#   '302 - Burnsville',
#   '401 - Millboro',
#   '501 - Healing Springs',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Bedford County': ['101 - Goodview Elem School (CD 5)',
#   '102 - Hardy Vol Fire Co (CD 5)',
#   '103 - Chamblissburg Baptist Church (CD 5)',
#   '104 - Stewartsville Rescue Squad (CD 5)',
#   '201 - Bedford Christian Church (CD 5)',
#   '202 - Staunton River High School (CD 5)',
#   '203 - Moneta Elem School (CD 5)',
#   '204 - Quaker Baptist Church (CD 5)',
#   '205 - Saunders Vol Fire Co (CD 5)',
#   '301 - New London Academy (CD 6)',
#   '302 - Bedford Regional Water Auth (CD 5)',
#   '303 - Bethesda United Methodist Church (CD 5)',
#   '304 - Forest Youth Athletic Assoc (CD 6)',
#   '305 - Huddleston Elem School (CD 5)',
#   '401 - Forest Elementary School (CD 6)',
#   '402 - Thomas Jefferson Elem School (CD 6)',
#   '403 - Knights Of Columbus Bldg (CD 6)',
#   '404 - St. Paul Baptist Church (CD 6)',
#   '502 - Big Island Elem School (CD 6)',
#   '503 - Sedalia Center (CD 6)',
#   '504 - Suck Springs Baptist Church (CD 6)',
#   '505 - Boonsboro Elementary School (CD 6)',
#   '506 - Boonsboro Ruritan Club (CD 6)',
#   '601 - Montvale Elem School (CD 6)',
#   '602 - Shady Grove Fire Department (CD 5)',
#   '603 - Thaxton Baptist Church #1 (CD 5)',
#   '604 - Bedford Welcome Center (CD 5)',
#   '701 - Goode Vol Rescue Squad (CD 5)',
#   '702 - Liberty High School (CD 5)',
#   '703 - Thaxton Baptist Church #2 (CD 5)',
#   '704 - Bedford Central Library (CD 5)',
#   'Ab - Central Absentee Precinct (CD 5)',
#   'Ab - Central Absentee Precinct (CD 6)',
#   'Provisional (CD 5)',
#   'Provisional (CD 6)'],
#  'Bland County': ['101 - Bastian',
#   '102 - Ceres',
#   '201 - Davis',
#   '202 - Seddon',
#   '301 - Hollybrook',
#   '302 - Mechanicsburg',
#   '401 - Rocky Gap',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Botetourt County': ['101 - Daleville',
#   '102 - Greenfield',
#   '201 - Blue Ridge',
#   '202 - Rainbow Forest',
#   '301 - Buchanan',
#   '302 - Mill Creek',
#   '403 - Eagle Rock',
#   '406 - Fincastle',
#   '501 - Troutville',
#   '502 - Cloverdale',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Bristol City': ['1 - First Ward',
#   '2 - Second Ward',
#   '3 - Third Ward',
#   '4 - Fourth Ward',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Brunswick County': ['101 - Brodnax',
#   '102 - Rock Store',
#   '103 - Tillman',
#   '201 - Dromgoole',
#   '202 - Edgerton',
#   '203 - Fitzhugh',
#   '301 - Alberta',
#   '302 - Danieltown',
#   '303 - Elmore',
#   '304 - Seymour',
#   '401 - Sturgeon',
#   "402 - King's Store",
#   '501 - Totaro',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Buchanan County': ['102 - Blackey',
#   '103 - Hurley',
#   '201 - Grassy',
#   '202 - Bull',
#   '203 - Rocklick',
#   '301 - Slate',
#   '302 - North Grundy',
#   '403 - South Grundy',
#   '404 - Oakwood',
#   '501 - Prater',
#   '502 - Fox',
#   '503 - Vansant',
#   '601 - Council',
#   '602 - Garden',
#   '603 - Hurricane',
#   '701 - Whitewood',
#   '702 - Contrary',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Buckingham County': ['101 - New Canton',
#   '102 - Georgia Creek',
#   '201 - White Hall',
#   '301 - Curdsville',
#   '302 - New Store',
#   '401 - Maysville',
#   '501 - Wrights',
#   '502 - Glenmore',
#   '601 - Slate River',
#   '701 - Gold Hill',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Buena Vista City': ['1 - First Ward', '2 - Second Ward'],
#  'Campbell County': ['101 - Brookville',
#   '102 - New London',
#   '201 - Walker',
#   '202 - Bedford Springs',
#   '301 - Evington',
#   '302 - Otter River',
#   '303 - Altavista',
#   '401 - Three Forks',
#   '402 - Court House',
#   '501 - Spring Hill',
#   '502 - Yellow Branch',
#   '601 - Kings',
#   '602 - Concord',
#   '701 - Brookneal',
#   '702 - Gladys',
#   '703 - Morris Church',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Caroline County': ['101 - Bowling Green',
#   '102 - Sparta',
#   '201 - North Madison',
#   '202 - South Madison',
#   '301 - Port Royal',
#   '302 - Woodford',
#   '401 - Dawn',
#   '402 - Carmel Church',
#   '501 - West Mattaponi',
#   '502 - Milford',
#   '601 - Chilesburg',
#   '602 - Lake',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Carroll County': ['101 - Mt Bethel',
#   '102 - St Paul',
#   '103 - Lambsburg',
#   '105 - Fancy Gap',
#   '201 - Hillsville B',
#   '202 - Laurel Fork',
#   '203 - Gladesboro',
#   '301 - Hillsville C',
#   '302 - Sylvatus',
#   '303 - Dugspur',
#   '402 - Woodlawn D',
#   '403 - Oakland D',
#   '405 - Oakland A',
#   '406 - Woodlawn F',
#   '501 - Vaughan',
#   '502 - Gladeville',
#   '503 - Woodlawn E',
#   '504 - Laurel',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Charles City County': ['101 - Precinct 1-1',
#   '201 - Precinct 2-1',
#   '301 - Precinct 3-1',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Charlotte County': ['101 - County Seat',
#   '201 - Red Oak Wylliesburg',
#   '302 - Drakes Branch',
#   '401 - Keysville',
#   '501 - Cullen/Red House',
#   '602 - Phenix',
#   '702 - Bacon/Saxe',
#   'Ab - Central Absentee Precinct'],
#  'Charlottesville City': ['101 - Recreation',
#   '102 - Clark',
#   '201 - Carver',
#   '202 - Walker',
#   '301 - Benjamin Tonsler',
#   '302 - Johnson',
#   '303 - Buford',
#   '401 - Venable',
#   '402 - Alumni Hall',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Chesapeake City': ['1 - Great Bridge (CD 4)',
#   '2 - Bethel (CD 4)',
#   '3 - Camelot (CD 3)',
#   '4 - Churchland (CD 3)',
#   '5 - Crestwood (CD 3)',
#   '6 - Deep Creek (CD 4)',
#   '7 - Greenbrier (CD 4)',
#   '8 - South Norfolk Recreation (CD 3)',
#   '9 - Bells Mill (CD 4)',
#   '10 - Oscar Smith (CD 3)',
#   '11 - Geneva Park (CD 3)',
#   '12 - Georgetown (CD 3)',
#   '13 - Gilmerton (CD 3)',
#   '14 - Grassfield (CD 4)',
#   '15 - B M Williams (CD 3)',
#   '16 - Hickory Grove (CD 4)',
#   '17 - Indian Creek (CD 4)',
#   '18 - Indian River (CD 3)',
#   '19 - Jolliff (CD 4)',
#   '20 - E W Chittum (CD 3)',
#   '20 - E W Chittum (CD 4)',
#   '21 - Fellowship (CD 3)',
#   '22 - Norfolk Highlands (CD 3)',
#   '23 - Oak Grove (CD 4)',
#   '24 - Oaklette (CD 3)',
#   '25 - St Julians (CD 3)',
#   '26 - Johnson Park (CD 3)',
#   '27 - Silverwood (CD 3)',
#   '28 - Sunray I (CD 4)',
#   '29 - Tanglewood (CD 3)',
#   '30 - South Norfolk (CD 3)',
#   '31 - Carver School (CD 3)',
#   '32 - Providence (CD 3)',
#   '33 - Westover (CD 3)',
#   '34 - Hickory Middle School (CD 4)',
#   '35 - Taylor Road (CD 3)',
#   '36 - Great Bridge Baptist Church (CD 4)',
#   '37 - Bridgetown (CD 4)',
#   '38 - Bailey Creek (CD 3)',
#   '39 - Lake Drummond (CD 4)',
#   '40 - River Birch (CD 3)',
#   '41 - John T West (CD 4)',
#   '42 - Parkways (CD 3)',
#   '43 - Pleasant Crossing (CD 4)',
#   '44 - Nansemond (CD 3)',
#   '45 - Sunray II (CD 4)',
#   '46 - Bells Mill II (CD 4)',
#   '47 - Green Sea (CD 4)',
#   '48 - Jolliff Middle School (CD 4)',
#   '49 - Waterway (CD 4)',
#   '50 - River Walk (CD 4)',
#   '51 - Coopers Way (CD 4)',
#   '52 - Shipyard Road (CD 4)',
#   '53 - Fairways (CD 3)',
#   '54 - Pughsville (CD 3)',
#   '55 - Georgetown East (CD 3)',
#   '56 - Green Tree (CD 3)',
#   '57 - Cypress (CD 3)',
#   '58 - Expressway (CD 4)',
#   '59 - Clearfield (CD 4)',
#   '60 - Parker Road (CD 4)',
#   '61 - Centerville (CD 4)',
#   '62 - Fentress (CD 4)',
#   '63 - Poplar Branch (CD 4)',
#   'AB - Central Absentee Precinct (CD 3)',
#   'Ab - Central Absentee Precinct (CD 4)',
#   'Provisional (CD 3)',
#   'Provisional (CD 4)'],
#  'Chesterfield County': ['101 - Bellwood (CD 4)',
#   '102 - South Chester (CD 4)',
#   '103 - Enon (CD 4)',
#   '104 - North Chester (CD 4)',
#   '105 - Drewrys Bluff (CD 7)',
#   '106 - Harrowgate (CD 4)',
#   '107 - Wells (CD 4)',
#   '108 - Ecoff (CD 4)',
#   '109 - Elizabeth Scott (CD 4)',
#   '110 - Dutch Gap (CD 4)',
#   '111 - Iron Bridge (CD 4)',
#   '112 - Carver (CD 4)',
#   '201 - Gates (CD 4)',
#   '202 - Beulah (CD 7)',
#   '203 - Bird (CD 4)',
#   '204 - Jacobs (CD 7)',
#   '205 - Falling Creek (CD 7)',
#   '206 - Belmont (CD 7)',
#   '207 - Chippenham (CD 7)',
#   '208 - Meadowbrook (CD 7)',
#   '209 - Salem Church (CD 4)',
#   '210 - Five Forks (CD 7)',
#   '211 - Nash (CD 4)',
#   "212 - St. Luke's (CD 7)",
#   '213 - Southside (CD 7)',
#   '214 - Hopkins (CD 7)',
#   '215 - North Bird (CD 7)',
#   '301 - Ettrick (CD 4)',
#   '302 - Deer Run (CD 7)',
#   '303 - Matoaca (CD 4)',
#   '304 - Winfrees Store (CD 4)',
#   '305 - Beach (CD 4)',
#   '306 - Winterpock (CD 7)',
#   '307 - Cosby (CD 7)',
#   '308 - South Manchester (CD 7)',
#   '309 - Skinquarter (CD 7)',
#   '310 - Tomahawk (CD 7)',
#   '313 - Woolridge (CD 7)',
#   '315 - Bailey Bridge (CD 7)',
#   '316 - Spring Run (CD 7)',
#   '317 - Birkdale (CD 7)',
#   '318 - West Beach (CD 7)',
#   '401 - Harbour Pointe (CD 7)',
#   '402 - Genito (CD 7)',
#   '403 - Brandermill (CD 7)',
#   '404 - Providence (CD 7)',
#   '405 - La Prade (CD 7)',
#   '406 - Smoketree (CD 7)',
#   '407 - Monacan (CD 7)',
#   '408 - Reams (CD 7)',
#   '409 - Manchester (CD 7)',
#   '410 - Wagstaff (CD 7)',
#   '411 - Swift Creek (CD 7)',
#   '413 - Shenandoah (CD 7)',
#   '414 - Crenshaw (CD 7)',
#   '415 - Evergreen (CD 7)',
#   '416 - Evergreen West (CD 7)',
#   '417 - Edgewater (CD 7)',
#   '501 - Huguenot (CD 7)',
#   '502 - Crestwood (CD 7)',
#   '503 - Midlothian (CD 7)',
#   '504 - Robious (CD 7)',
#   '505 - Bon Air (CD 7)',
#   '506 - Greenfield (CD 7)',
#   '507 - Salisbury (CD 7)',
#   '508 - Belgrade (CD 7)',
#   '509 - Cranbeck (CD 7)',
#   '510 - Sycamore (CD 7)',
#   '511 - Black Heath (CD 7)',
#   '513 - Beaufont (CD 7)',
#   '514 - Watkins (CD 7)',
#   '515 - Davis (CD 7)',
#   '516 - Pocoshock (CD 7)',
#   '517 - Roseland (CD 7)',
#   '518 - Midlothian North (CD 7)',
#   'Ab - Central Absentee Precinct (CD 4)',
#   'Ab - Central Absentee Precinct (CD 7)',
#   'Provisional (CD 4)',
#   'Provisional (CD 7)'],
#  'Clarke County': ['101 - Russell',
#   '201 - Berryville',
#   '301 - Millwood',
#   '302 - Pine Grove',
#   '401 - White Post',
#   '501 - Buckmarsh',
#   '502 - Blue Ridge',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Colonial Heights City': ['1 - First',
#   '2 - Second',
#   '3 - Third',
#   '4 - Fourth',
#   '5 - Fifth',
#   'Ab - Central Absentee Precinct'],
#  'Covington City': ['101 - Precinct 1-1',
#   '201 - Precinct 2-1',
#   '301 - Precinct 3-1',
#   '401 - Precinct 4-1',
#   '501 - Precinct 5-1',
#   'Ab - Central Absentee Precinct'],
#  'Craig County': ['101 - Court House',
#   '201 - Ammendale Precinct',
#   '301 - Givens & Reynolds Store',
#   '303 - Marshalls Store',
#   '401 - Barbours Creek',
#   '402 - Paint Bank',
#   '403 - Craig Springs',
#   '501 - Craig City',
#   'Provisional'],
#  'Culpeper County': ['101 - West Fairfax',
#   '201 - East Fairfax',
#   '302 - Eggbornsville',
#   '303 - Cardova',
#   '304 - Willow Shade',
#   '401 - Eldorado',
#   '402 - Browns Store',
#   '501 - Jeffersonton',
#   '502 - Rixeyville',
#   '601 - Mitchells',
#   '602 - Pearl Sample',
#   '603 - South Ridge',
#   '702 - Brandy Station',
#   '703 - Lignum',
#   '704 - Richardsville',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Cumberland County': ['101 - Precinct 1',
#   '201 - Precinct 2',
#   '301 - Precinct 3',
#   '401 - Precinct 4',
#   '501 - Precinct 5',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Danville City': ['1 - Ward One',
#   '2 - Ward Two',
#   '3 - Ward Three',
#   '4 - Ward Four',
#   '6 - Ward Six',
#   '7 - Ward Seven',
#   '8 - Ward Eight',
#   '9 - Ward Nine',
#   '10 - Ward Ten',
#   '11 - Ward Eleven',
#   '12 - Ward Twelve',
#   '13 - Ward Thirteen',
#   '14 - Ward Fourteen',
#   '15 - Ward Fifteen',
#   '16 - Ward Sixteen',
#   '17 - Ward Seventeen',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Dickenson County': ['101 - South Clintwood',
#   '201 - Nora',
#   '202 - Frying Pan',
#   '203 - Clinchco',
#   '301 - West Dante',
#   '302 - Herald',
#   '303 - Ridge',
#   '401 - Haysi-colley',
#   '501 - Tarpon',
#   '502 - North Clintwood',
#   'Ab - Central Absentee Precinct'],
#  'Dinwiddie County': ['101 - White Oak',
#   '102 - Rocky Run',
#   '103 - Church Road',
#   '201 - Rohoic',
#   '202 - Sutherland',
#   '301 - Reams',
#   '302 - New Hope',
#   '303 - Little Zion',
#   '401 - Dinwiddie',
#   '402 - Mckenney',
#   '403 - Cherry Hill',
#   '501 - Edgehill',
#   '502 - Chesdin',
#   'Ab - Central Absentee Precinct'],
#  'Emporia City': ['101 - Precinct 1-1',
#   '201 - Precinct 2-1',
#   '301 - Precinct 3-1',
#   '401 - Precinct 4-1',
#   '501 - Precinct 5-1',
#   '601 - District 6',
#   '701 - District 7',
#   'Provisional'],
#  'Essex County': ['101 - Greater Tappahannock',
#   '201 - North',
#   '301 - South',
#   '401 - Central',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Fairfax County': ['104 - Chapel (CD 11)',
#   '105 - Fairview (CD 11)',
#   '106 - Heritage (CD 11)',
#   '108 - Kings Park (CD 11)',
#   '109 - Little Run (CD 11)',
#   '110 - North Springfield (CD 11)',
#   '113 - Canterbury (CD 11)',
#   '114 - Olde Creek (CD 11)',
#   '115 - Ravensworth (CD 11)',
#   '116 - Wakefield (CD 11)',
#   '117 - Woodson (CD 11)',
#   '118 - Lake Braddock (CD 11)',
#   '119 - Laurel (CD 11)',
#   '120 - Sideburn (CD 11)',
#   '121 - Villa (CD 11)',
#   '123 - Robinson (CD 11)',
#   '125 - Signal Hill (CD 11)',
#   '126 - Bonnie Brae (CD 11)',
#   '127 - Burke Centre (CD 11)',
#   '128 - Cardinal (CD 11)',
#   '129 - Keene Mill (CD 11)',
#   '130 - Terra Centre (CD 11)',
#   '131 - Eagle View (CD 11)',
#   '132 - Monument (CD 11)',
#   '133 - Danbury (CD 11)',
#   '134 - University (CD 11)',
#   '201 - Armstrong (CD 11)',
#   '202 - Flint Hill (CD 11)',
#   '203 - Floris (CD 11)',
#   '204 - Madison (CD 11)',
#   '208 - Reston #1 (CD 11)',
#   '209 - Reston #2 (CD 11)',
#   '213 - Vienna #1 (CD 11)',
#   '214 - Vienna #2 (CD 11)',
#   '216 - Vienna #4 (CD 11)',
#   '218 - Vienna #6 (CD 11)',
#   '219 - Westbriar (CD 11)',
#   '220 - Dogwood (CD 11)',
#   '221 - Hunters Woods (CD 11)',
#   '222 - Reston #3 (CD 11)',
#   '223 - Glade (CD 11)',
#   '224 - South Lakes (CD 11)',
#   '225 - Hughes (CD 11)',
#   '226 - Wolftrap (CD 11)',
#   '227 - Sunrise Valley (CD 11)',
#   '229 - Fox Mill (CD 10)',
#   '233 - North Point (CD 11)',
#   '234 - Aldrin (CD 11)',
#   '235 - Frying Pan (CD 11)',
#   '236 - Stuart (CD 11)',
#   '237 - Mcnair (CD 11)',
#   '238 - Cameron Glen (CD 11)',
#   '240 - Colvin (CD 10)',
#   '301 - Chain Bridge (CD 10)',
#   '302 - Chesterbrook (CD 8)',
#   '303 - Churchill (CD 10)',
#   '304 - Cooper (CD 10)',
#   '305 - El Nido (CD 8)',
#   '306 - Great Falls (CD 10)',
#   '307 - Haycock (CD 8)',
#   '309 - Kenmore (CD 10)',
#   '310 - Kirby (CD 8)',
#   '311 - Langley (CD 10)',
#   '312 - Longfellow (CD 8)',
#   '314 - Mclean (CD 10)',
#   '315 - Pimmit (CD 8)',
#   '316 - Salona #1 (CD 8)',
#   '317 - Westhampton (CD 8)',
#   '318 - Westmoreland (CD 8)',
#   '319 - Herndon #1 (CD 11)',
#   '320 - Herndon #2 (CD 11)',
#   '321 - Clearview (CD 10)',
#   '322 - Forestville (CD 10)',
#   '323 - Shouse (CD 10)',
#   '324 - Herndon #3 (CD 11)',
#   '325 - Hutchison (CD 11)',
#   '327 - Sugarland (CD 10)',
#   '328 - Hickory (CD 10)',
#   '329 - Seneca (CD 10)',
#   '331 - Spring Hill (CD 10)',
#   '332 - Coates (CD 11)',
#   '333 - Salona #2 (CD 8)',
#   '401 - Bush Hill (CD 8)',
#   '402 - Cameron (CD 8)',
#   '403 - Forestdale (CD 8)',
#   '404 - Franconia (CD 8)',
#   '405 - Groveton (CD 8)',
#   '406 - Hayfield (CD 8)',
#   '408 - Mount Eagle (CD 8)',
#   '409 - Pioneer (CD 8)',
#   '410 - Rose Hill (CD 8)',
#   '411 - Virginia Hills (CD 8)',
#   '413 - Fairfield (CD 8)',
#   '415 - Crestwood (CD 8)',
#   '417 - Garfield (CD 8)',
#   '418 - Lynbrook (CD 8)',
#   '419 - Lane (CD 8)',
#   '420 - Villages (CD 8)',
#   '421 - Kingstowne (CD 8)',
#   '422 - Van Dorn (CD 8)',
#   '423 - Clermont (CD 8)',
#   '424 - Huntley (CD 8)',
#   '426 - Greenspring (CD 11)',
#   '427 - Island Creek (CD 8)',
#   '428 - Pinewood (CD 8)',
#   '429 - Hybla Valley (CD 8)',
#   '501 - Baileys (CD 8)',
#   '502 - Barcroft (CD 11)',
#   '503 - Belvedere (CD 11)',
#   '504 - Bristow (CD 11)',
#   '505 - Glen Forest (CD 8)',
#   '506 - Holmes #1 (CD 8)',
#   '507 - Lincolnia (CD 8)',
#   '508 - Masonville (CD 11)',
#   '509 - Plaza (CD 8)',
#   '510 - Parklawn (CD 8)',
#   '511 - Ravenwood (CD 11)',
#   '512 - Sleepy Hollow (CD 11)',
#   '513 - Saint Albans (CD 11)',
#   '513 - Saint Albans (CD 8)',
#   '514 - Crossroads (CD 8)',
#   '515 - Westlawn (CD 8)',
#   '516 - Weyanoke (CD 8)',
#   '517 - Willston (CD 8)',
#   '518 - Columbia (CD 11)',
#   '519 - Hummer (CD 11)',
#   '520 - Skyline (CD 8)',
#   '521 - Brook Hill (CD 8)',
#   '522 - Camelot (CD 11)',
#   '523 - Poe (CD 8)',
#   '525 - Walnut Hill (CD 8)',
#   '526 - Bren Mar (CD 8)',
#   '527 - Edsall (CD 8)',
#   '528 - Ridgelea (CD 11)',
#   '530 - Holmes #2 (CD 11)',
#   '601 - Belle Haven (CD 8)',
#   '602 - Belleview (CD 8)',
#   '604 - Bucknell (CD 8)',
#   '605 - Fort Hunt (CD 8)',
#   '606 - Hollin Hall (CD 8)',
#   '607 - Huntington (CD 8)',
#   '608 - Kirkside (CD 8)',
#   '609 - Marlan (CD 8)',
#   '610 - Sherwood (CD 8)',
#   '611 - Stratford (CD 8)',
#   '612 - Waynewood (CD 8)',
#   '613 - Westgate (CD 8)',
#   '614 - Riverside (CD 8)',
#   '615 - Woodley (CD 8)',
#   '616 - Gunston (CD 8)',
#   '617 - Lorton (CD 8)',
#   '618 - Newington (CD 11)',
#   '619 - Belvoir (CD 8)',
#   '621 - Grosvenor (CD 8)',
#   '622 - Lorton Station (CD 8)',
#   '623 - Alban (CD 8)',
#   '625 - Lorton Center (CD 8)',
#   '626 - Saratoga (CD 8)',
#   '627 - Woodlawn (CD 8)',
#   '628 - Laurel Hill (CD 11)',
#   '629 - South County (CD 11)',
#   '701 - Blake (CD 11)',
#   '703 - Fort Buffalo (CD 8)',
#   '704 - Freedom Hill (CD 11)',
#   '705 - Graham - Greenway (CD 8)',
#   '707 - Mantua (CD 11)',
#   '708 - Marshall (CD 8)',
#   '709 - Mosby (CD 11)',
#   '710 - Pine Spring (CD 8)',
#   '711 - Price (CD 11)',
#   '712 - Shreve (CD 8)',
#   '713 - Timber Lane (CD 8)',
#   '714 - Walker (CD 11)',
#   '717 - Woodburn (CD 11)',
#   '718 - Pine Ridge (CD 11)',
#   '720 - Thoreau (CD 11)',
#   '721 - Merrifield (CD 11)',
#   '726 - Magarity (CD 8)',
#   '727 - Oakton (CD 11)',
#   '729 - Nottoway (CD 11)',
#   '730 - Penderbrook (CD 11)',
#   '731 - Tysons (CD 11)',
#   '732 - Oak Marr (CD 11)',
#   '733 - Kilmer (CD 11)',
#   '734 - Hunters Branch (CD 11)',
#   '735 - Rotonda (CD 11)',
#   '801 - Burke (CD 11)',
#   '802 - Cedar Lake (CD 11)',
#   '803 - Clifton (CD 10)',
#   '804 - Colchester (CD 10)',
#   '805 - Fairfax Station (CD 10)',
#   '806 - Sydenstricker (CD 11)',
#   '807 - Hunt Valley (CD 11)',
#   '811 - Pohick (CD 11)',
#   '812 - Valley (CD 11)',
#   '815 - Woodyard (CD 10)',
#   '824 - Orange (CD 11)',
#   '825 - Cherry Run (CD 11)',
#   '827 - Irving (CD 11)',
#   '833 - White Oaks (CD 11)',
#   '838 - Sangster (CD 10)',
#   '839 - Silverbrook (CD 10)',
#   '840 - West Springfield (CD 11)',
#   '841 - Popes Head (CD 10)',
#   '842 - Parkway (CD 11)',
#   '843 - Fair Lakes (CD 11)',
#   '844 - Centerpointe (CD 11)',
#   '845 - Fountainhead (CD 10)',
#   '846 - Greenbriar East (CD 11)',
#   '847 - Greenbriar West (CD 10)',
#   '848 - Fair Oaks (CD 11)',
#   '849 - Newgate North (CD 10)',
#   '850 - South Run (CD 10)',
#   '851 - Willow Springs (CD 11)',
#   '854 - Newgate South (CD 10)',
#   '901 - Centre Ridge (CD 11)',
#   '902 - Brookfield (CD 10)',
#   '903 - Cub Run (CD 10)',
#   '904 - Stonecroft (CD 10)',
#   '905 - Franklin (CD 10)',
#   '908 - Hidden Meadow (CD 10)',
#   '909 - Oak Hill (CD 10)',
#   '910 - London Towne (CD 11)',
#   '911 - Navy (CD 10)',
#   '913 - Rocky Run (CD 10)',
#   '914 - Vale (CD 10)',
#   '915 - Virginia Run (CD 10)',
#   '916 - Waples Mill (CD 10)',
#   '917 - Stone North (CD 10)',
#   '918 - Centreville (CD 11)',
#   '919 - Green Trails (CD 11)',
#   '920 - Chantilly (CD 10)',
#   '921 - Deer Park (CD 10)',
#   '923 - Bull Run (CD 10)',
#   '924 - Spindle (CD 11)',
#   '925 - Old Mill (CD 10)',
#   '926 - Powell (CD 11)',
#   '927 - Armfield (CD 10)',
#   '928 - Poplar Tree (CD 10)',
#   '929 - Difficult Run (CD 10)',
#   '930 - Lees Corner (CD 10)',
#   '931 - Carson (CD 10)',
#   '932 - Stone South (CD 10)',
#   '933 - Compton (CD 11)',
#   'Ab - Central Absentee Precinct (CD 10)',
#   'Ab - Central Absentee Precinct (CD 11)',
#   'Ab - Central Absentee Precinct (CD 8)',
#   'Provisional (CD 10)',
#   'Provisional (CD 11)',
#   'Provisional (CD 8)'],
#  'Fairfax City': ['1 - One',
#   '2 - Two',
#   '3 - Three',
#   '4 - Four',
#   '5 - Five',
#   '6 - Six',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Falls Church City': ['1 - First Ward',
#   '2 - Second Ward',
#   '3 - Third Ward',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Fauquier County': ['101 - Kettle Run (CD 5)',
#   '102 - Catlett (CD 1)',
#   '103 - Casanova (CD 5)',
#   '104 - Lois (CD 1)',
#   '105 - Opal (CD 5)',
#   '106 - Baldwin Ridge (CD 5)',
#   '201 - Courthouse (CD 5)',
#   '202 - Airlie (CD 5)',
#   '203 - Warrenton (CD 5)',
#   '301 - Morrisville (CD 1)',
#   '302 - Remington (CD 5)',
#   '303 - Bealeton (CD 1)',
#   '401 - Marshall (CD 5)',
#   '402 - Leeds (CD 5)',
#   '403 - Waterloo (CD 5)',
#   '404 - Springs Valley (CD 5)',
#   '501 - The Plains (CD 5)',
#   '502 - New Baltimore (CD 5)',
#   '503 - Broad Run (CD 5)',
#   '504 - Vint Hill (CD 5)',
#   'Ab - Central Absentee Precinct (CD 1)',
#   'Ab - Central Absentee Precinct (CD 5)',
#   'Provisional (CD 1)',
#   'Provisional (CD 5)'],
#  'Floyd County': ['101 - Locust Grove',
#   '201 - Little River',
#   '301 - Courthouse',
#   '401 - Burks Fork',
#   '501 - Indian Valley',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Fluvanna County': ['101 - Palmyra',
#   '201 - Columbia',
#   '301 - Fork Union',
#   '401 - Cunningham',
#   '501 - Rivanna',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Franklin County': ['102 - Burnt Chimney',
#   '103 - Scruggs',
#   '201 - Glade Hill',
#   '202 - Penhook',
#   '203 - Hodgesville',
#   '204 - Dudley',
#   '301 - Snow Creek',
#   '302 - Fork Mountain',
#   '303 - Sontag',
#   '304 - Dickinson',
#   '401 - Henry',
#   '402 - Ferrum',
#   '403 - Endicott',
#   '501 - Waidsboro',
#   '502 - Callaway',
#   '503 - Bowmans',
#   '504 - Gogginsville',
#   '601 - Boones Mill',
#   '602 - Bonbrook',
#   '603 - Coopers Cove',
#   '701 - Rocky Mount East',
#   '702 - Rocky Mount West',
#   '703 - Rocky Mount South',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Franklin City': ['101 - Precinct 1-1',
#   '201 - Precinct 2-1',
#   '301 - Precinct 3-1',
#   '401 - Precinct 4-1',
#   '501 - Precinct 5-1',
#   '601 - Precinct 6-1',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Frederick County': ['101 - Russells',
#   '102 - Gore',
#   '103 - Kernstown',
#   '104 - Cedar Creek',
#   '201 - Gainesborough',
#   '202 - Albin',
#   '203 - Redland',
#   '204 - Nain',
#   '301 - Clear Brook',
#   "302 - Neff's Town",
#   '303 - White Hall',
#   '401 - Carpers Valley',
#   '402 - Shenandoah',
#   "403 - Parkin's Mill",
#   '404 - Armel',
#   '501 - Stephens City',
#   '502 - Newtown',
#   '503 - Canterburg',
#   '601 - Millbrook',
#   '602 - Ash Hollow',
#   '603 - Greenwood',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Fredericksburg City': ['101 - Precinct 1 - District One',
#   '201 - Precinct 1 - District Two',
#   '301 - Precinct 1 - District Three',
#   '401 - Precinct 1 - District Four',
#   '402 - Precinct 2 - District Four',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Galax City': ['1 - East',
#   '2 - North',
#   '3 - South',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Giles County': ['101 - Glen Lyn',
#   '102 - Rich Creek',
#   '103 - Narrows',
#   '201 - Pearisburg',
#   '202 - Staffordsville',
#   '203 - White Gate',
#   '301 - Eggleston',
#   '302 - Pembroke',
#   '303 - Newport',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Gloucester County': ['101 - Harcum',
#   '102 - Salem',
#   '103 - Peasley',
#   '201 - Courthouse',
#   '202 - Botetourt',
#   '301 - White Marsh',
#   '302 - Roanes',
#   '401 - Hayes',
#   '402 - Sarahs Creek',
#   '501 - Achilles',
#   '502 - Walker',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Goochland County': ['101 - Fife',
#   '102 - Hadensville',
#   '201 - Three Square',
#   '202 - Sandy Hook',
#   '301 - Goochland Court House 1',
#   '302 - Goochland Court House 2',
#   '401 - Shallow Well',
#   '402 - Centerville',
#   '501 - Manakin',
#   '502 - Blair Road',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Grayson County': ['101 - Bridle Creek',
#   '102 - Flatridge',
#   '103 - Grant',
#   '104 - Mouth Of Wilson',
#   '105 - Mount Rogers',
#   '106 - Rugby',
#   '107 - Troutdale',
#   '108 - Comers Rock',
#   '202 - Elk Creek',
#   '203 - Independence',
#   '301 - Baywood',
#   '302 - Fairview',
#   '401 - Fries',
#   '402 - Providence',
#   '403 - Oldtown',
#   'Ab - Central Absentee Precinct'],
#  'Greene County': ['101 - Dyke',
#   '102 - Swift Run',
#   '201 - Ruckersville',
#   '301 - Stanardsville',
#   '401 - Midway',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Greensville County': ['101 - Precinct 1-a',
#   '102 - Precinct 1-b',
#   '103 - Precinct 1-c',
#   '201 - Precinct 2-a',
#   '202 - Precinct 2-b',
#   '302 - Precinct 3-a',
#   '401 - Precinct 4-a',
#   '402 - Precinct 4-b',
#   '403 - Precinct 4-c',
#   'Provisional'],
#  'Halifax County': ['101 - Childrey',
#   '102 - Liberty',
#   '103 - Republican Grove',
#   '201 - Clays Mill',
#   '202 - Crossroads',
#   '203 - Clover',
#   '302 - Meadville',
#   '304 - Vernon Hill',
#   '305 - Sinai',
#   '401 - Courthouse',
#   '403 - Center',
#   '502 - Dan River',
#   '503 - Scottsburg',
#   '601 - Black Walnut',
#   '603 - Mt Carmel',
#   '605 - Union',
#   '701 - Hyco',
#   '702 - Midway',
#   '703 - Virgilina',
#   '801 - South Boston East',
#   '802 - South Boston West',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Hampton City': ['101 - Aberdeen (CD 3)',
#   '102 - Bassette (CD 3)',
#   '103 - City Hall (CD 3)',
#   '104 - Cooper (CD 3)',
#   '105 - East Hampton (CD 3)',
#   '106 - Armstrong (CD 3)',
#   '107 - Lindsay (CD 3)',
#   '108 - Thomas (CD 3)',
#   '109 - Phenix (CD 3)',
#   '110 - Phoebus (CD 2)',
#   '111 - Hampton Library (CD 3)',
#   '112 - Smith (CD 3)',
#   '115 - Wythe (CD 3)',
#   '116 - Jones (CD 3)',
#   '117 - Kecoughtan (CD 3)',
#   '118 - Mallory (CD 3)',
#   '201 - Booker (CD 2)',
#   '202 - Bryan (CD 2)',
#   '203 - Burbank (CD 2)',
#   '204 - Forrest (CD 3)',
#   '205 - Asbury (CD 2)',
#   '208 - Kraft (CD 3)',
#   '209 - Langley (CD 2)',
#   '210 - Machen (CD 3)',
#   '212 - Bethel (CD 3)',
#   '213 - Phillips (CD 2)',
#   '214 - Tucker Capps (CD 3)',
#   '215 - Tyler (CD 2)',
#   '215 - Tyler (CD 3)',
#   '216 - Sandy Bottom (CD 3)',
#   '217 - Syms (CD 3)',
#   'Ab - Central Absentee Precinct (CD 2)',
#   'Ab - Central Absentee Precinct (CD 3)',
#   'Provisional (CD 2)',
#   'Provisional (CD 3)'],
#  'Hanover County': ['101 - Ashland',
#   '104 - Sliding Hill',
#   '105 - Berkley',
#   '106 - Kersey Creek',
#   '107 - Chickahominy',
#   '201 - Beaverdam',
#   '202 - Blunts',
#   '203 - Wilmington Parish',
#   '206 - Courthouse',
#   '208 - Oak Knoll',
#   '209 - West Hanover',
#   '210 - Oak Hill',
#   '301 - Clay',
#   '303 - Shady Grove',
#   '304 - Atlee',
#   '305 - Cool Spring',
#   '401 - Battlefield',
#   '403 - Cold Harbor',
#   '404 - Black Creek',
#   '405 - Pebble Creek',
#   '406 - Beaverdam Creek',
#   '502 - Rural Point',
#   '503 - Newman',
#   '504 - Studley',
#   '505 - Totopotomoy',
#   '506 - Georgetown',
#   '507 - Laurel Meadow',
#   '601 - Village',
#   '602 - Lee Davis',
#   '603 - Mechanicsville',
#   '604 - Hanover Grove',
#   '701 - Farrington',
#   '702 - Montpelier',
#   '703 - Rockville',
#   '704 - Elmont',
#   '705 - South Anna',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Harrisonburg City': ['101 - Northeast',
#   '102 - East Central',
#   '103 - Southeast',
#   '104 - East',
#   '105 - South East Central',
#   '201 - Northwest',
#   '202 - Southwest',
#   '203 - West',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Henrico County': ['101 - Coalpit (CD 7)',
#   '102 - Dumbarton (CD 7)',
#   '103 - Glen Allen (CD 7)',
#   '104 - Glenside (CD 7)',
#   '105 - Greendale (CD 7)',
#   '106 - Hermitage (CD 7)',
#   '107 - Hilliard (CD 7)',
#   '108 - Hungary Creek (CD 7)',
#   '109 - Hunton (CD 7)',
#   '110 - Johnson (CD 7)',
#   '111 - Lakeside (CD 7)',
#   '112 - Longan (CD 7)',
#   '113 - Maude Trevvett (CD 7)',
#   '114 - Monument Hills (CD 7)',
#   '115 - Staples Mill (CD 7)',
#   '116 - Summit Court (CD 7)',
#   '117 - Westwood (CD 7)',
#   '201 - Adams (CD 4)',
#   '202 - Azalea (CD 7)',
#   '203 - Belmont (CD 7)',
#   '204 - Brookland (CD 7)',
#   '205 - Canterbury (CD 7)',
#   '206 - Central Gardens (CD 4)',
#   '207 - Chamberlayne (CD 7)',
#   '208 - Fairfield (CD 4)',
#   '209 - Glen Lea (CD 4)',
#   '210 - Greenwood (CD 7)',
#   '211 - Highland Gardens (CD 4)',
#   '212 - Hollybrook (CD 7)',
#   '213 - Hungary (CD 7)',
#   '214 - Longdale (CD 7)',
#   '215 - Maplewood (CD 4)',
#   '216 - Moody (CD 7)',
#   '217 - Mountain (CD 7)',
#   '218 - Oakview (CD 7)',
#   '219 - Randolph (CD 7)',
#   '220 - Ratcliffe (CD 4)',
#   '221 - Stratford Hall (CD 7)',
#   '222 - Wilder (CD 7)',
#   '223 - Yellow Tavern (CD 7)',
#   '224 - Essex Village (CD 4)',
#   '301 - Causeway (CD 7)',
#   '302 - Cedarfield (CD 7)',
#   '303 - Innsbrook (CD 7)',
#   '304 - Jackson Davis (CD 7)',
#   '305 - Nuckols Farm (CD 7)',
#   '306 - Pocahontas (CD 7)',
#   '307 - Ridge (CD 7)',
#   '308 - Rivers Edge (CD 7)',
#   '309 - Sadler (CD 7)',
#   '310 - Shady Grove (CD 7)',
#   '311 - Short Pump (CD 7)',
#   '312 - Springfield (CD 7)',
#   '313 - Stoney Run (CD 7)',
#   '314 - Three Chopt (CD 7)',
#   '315 - Tucker (CD 7)',
#   '401 - Quioccasin (CD 7)',
#   '402 - Crestview (CD 7)',
#   '403 - Derbyshire (CD 7)',
#   '404 - Freeman (CD 7)',
#   '405 - Gayton (CD 7)',
#   '406 - Godwin (CD 7)',
#   '407 - Lakewood (CD 7)',
#   '408 - Lauderdale (CD 7)',
#   '409 - Maybeury (CD 7)',
#   '410 - Mooreland (CD 7)',
#   '411 - Pemberton (CD 7)',
#   '412 - Pinchbeck (CD 7)',
#   '413 - Ridgefield (CD 7)',
#   '414 - Rollingwood (CD 7)',
#   '415 - Skipwith (CD 7)',
#   '416 - Spottswood (CD 7)',
#   '417 - Tuckahoe (CD 7)',
#   '418 - Welborne (CD 7)',
#   '419 - West End (CD 7)',
#   '501 - Antioch (CD 4)',
#   '502 - Cedar Fork (CD 4)',
#   '503 - Chickahominy (CD 4)',
#   '504 - Donahoe (CD 4)',
#   '505 - Dorey (CD 4)',
#   '506 - Eanes (CD 4)',
#   '507 - Elko (CD 4)',
#   '508 - Highland Springs (CD 4)',
#   '509 - Laburnum (CD 4)',
#   '510 - Mehfoud (CD 4)',
#   '511 - Montrose (CD 4)',
#   '512 - Nine Mile (CD 4)',
#   '513 - Pleasants (CD 4)',
#   '514 - Rolfe (CD 4)',
#   '515 - Sandston (CD 4)',
#   '516 - Sullivans (CD 4)',
#   '517 - Town Hall (CD 4)',
#   '518 - Whitlocks (CD 4)',
#   'AB - Central Absentee Precinct (CD 4)',
#   'Ab - Central Absentee Precinct (CD 7)',
#   'Provisional (CD 4)',
#   'Provisional (CD 7)'],
#  'Henry County': ['101 - Bassett Number Two (CD 9)',
#   '102 - Gunville (CD 9)',
#   "103 - Scott's Tanyard (CD 9)",
#   '201 - Fieldale (CD 9)',
#   '202 - Horsepasture #1 (CD 9)',
#   '203 - Horsepasture #2 (CD 9)',
#   '204 - Spencer (CD 9)',
#   '302 - Axton (CD 5)',
#   '303 - Irisburg (CD 5)',
#   '304 - Mount Olivet (CD 5)',
#   '304 - Mount Olivet (CD 9)',
#   '305 - Mountain Valley (CD 5)',
#   '401 - Collinsville Number 1 (CD 9)',
#   '402 - Daniels Creek (CD 9)',
#   '404 - Collinsville Number 2 (CD 9)',
#   '405 - Mountain View (CD 5)',
#   '501 - Bassett Number One (CD 9)',
#   '502 - Figsboro (CD 9)',
#   '503 - Stanleytown (CD 9)',
#   '504 - Oak Level (CD 9)',
#   '505 - Dyers Store (CD 5)',
#   '505 - Dyers Store (CD 9)',
#   '601 - Fontaine (CD 9)',
#   '602 - Hillcrest (CD 9)',
#   '603 - Ridgeway #1 (CD 5)',
#   '604 - Ridgeway #2 (CD 9)',
#   'Ab - Central Absentee Precinct (CD 5)',
#   'Ab - Central Absentee Precinct (CD 9)',
#   'Provisional (CD 9)'],
#  'Highland County': ['1 - Monterey',
#   '3 - Wilsons Mill',
#   '5 - Blue Grass',
#   '7 - Mill Gap',
#   '8 - Mcdowell',
#   '10 - Headwaters'],
#  'Hopewell City': ['101 - Ward One',
#   '201 - Ward Two',
#   '301 - Ward Three',
#   '401 - Ward Four',
#   '501 - Ward Five',
#   '601 - Ward Six',
#   '701 - Ward Seven',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Isle of Wight County': ['101 - Smithfield',
#   '102 - Cypress Creek',
#   '201 - Bartlett',
#   '202 - Carrollton',
#   '301 - Rushmere',
#   '302 - Pons',
#   '401 - Courthouse',
#   '402 - Windsor',
#   '403 - Longview',
#   '501 - Walters',
#   '502 - Camps Mill',
#   '503 - Carrsville',
#   '504 - Zuni',
#   '505 - Raynor',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'James City County': ['101 - Berkeley A',
#   '102 - Berkeley B',
#   '103 - Berkeley C',
#   '104- Berkeley D',
#   '201 - Jamestown A',
#   '202 - Jamestown B',
#   '203 - Jamestown C',
#   '204 - Jamestown D',
#   '301 - Powhatan A',
#   '302 - Powhatan B',
#   '303 - Powhatan C',
#   '304 - Powhatan D',
#   '401 - Stonehouse A',
#   '402 - Stonehouse B',
#   '403 - Stonehouse C',
#   '501 - Roberts A',
#   '502 - Roberts B',
#   '503 - Roberts C',
#   '504 - Roberts D',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'King and Queen County': ['101 - Owenton',
#   '201 - Clarks',
#   '301 - Shacklefords',
#   '401 - Courthouse',
#   '501 - Oldmill',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'King George County': ['101 - Courthouse',
#   '102 - Passapatanzy',
#   '201 - Monroe',
#   '301 - Dahlgren',
#   '401 - Shiloh',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'King William County': ['101 - West Point',
#   '201 - Sweet Hall',
#   '202 - Courthouse',
#   '301 - Aylett',
#   '401 - Manquin',
#   '501 - Mangohick',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Lancaster County': ['101 - Precinct 1-1',
#   '201 - Precinct 2-1',
#   '301 - Precinct 3-1',
#   '302 - Precinct 3-2',
#   '401 - Precinct 4-1',
#   '501 - Precinct 5-1',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Lee County': ['101 - Elydale',
#   '102 - Ewing',
#   '103 - Rose Hill',
#   '201 - Blackwater',
#   '202 - Flatwoods',
#   '203 - Jonesville',
#   '301 - Ben Hur',
#   '302 - Woodway',
#   '401 - Stickleyville',
#   '402 - Jasper',
#   '403 - Seminary',
#   '404 - Dryden',
#   '501 - Saint Charles',
#   '502 - Pennington',
#   '503 - Robbins Chapel',
#   '504 - Keokee',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Lexington City': ['1 - Lexington', 'Ab - Central Absentee Precinct'],
#  'Loudoun County': ['107 - Little River',
#   '108 - Mercer',
#   '112 - Freedom',
#   '114 - Dulles South',
#   '117 - Carter',
#   '118 - Moorefield',
#   '119 - Arcola',
#   '120 - Lunsford',
#   '121 - Town Hall',
#   '122 - Hutchison Farm',
#   '123 - Cardinal Ridge',
#   '124 - Liberty',
#   '125 - Rock Ridge',
#   '207 - River Bend',
#   '208 - Algonkian',
#   '209 - Potomac Falls',
#   '210 - Cascades',
#   '213 - Countryside',
#   '214 - Sugarland North',
#   '215 - Sugarland South',
#   '216 - Lowes Island',
#   '217 - South Bank',
#   '218 - University Center',
#   '219 - Galilee Church',
#   '301 - Purcellville',
#   '302 - Round Hill',
#   '303 - Hillsboro',
#   '305 - Philomont',
#   '307 - Middleburg',
#   '308 - St Louis',
#   '309 - Aldie',
#   '310 - Mountain View',
#   '311 - Round Hill Elementary',
#   '312 - Briar Woods',
#   '313 - Pinebrook',
#   '314 - Legacy',
#   '315 - Firehouse',
#   "316 - Creighton's Corner",
#   "318 - Madison's Trust",
#   '401 - West Lovettsville',
#   '402 - Waterford',
#   '403 - Lucketts',
#   '407 - Harper Park',
#   '408 - Evergreen',
#   '409 - Clarkes Gap',
#   '411 - East Lovettsville',
#   '413 - Tuscarora',
#   '414 - Red Rock',
#   '416 - Hamilton',
#   '419 - J. L. Simpson',
#   '420 - River Creek',
#   '421 - Between The Hills',
#   '501 - West Leesburg',
#   '502 - East Leesburg',
#   '503 - Dry Mill',
#   '504 - Smarts Mill',
#   '505 - Cool Spring',
#   '506 - Brandon Park',
#   '507 - Greenway',
#   '508 - Balls Bluff',
#   '509 - Tolbert',
#   '510 - Heritage',
#   '615 - Hillside',
#   '616 - Eagle Ridge',
#   '617 - Oak Grove',
#   '619 - Ridgetop',
#   '620 - Russell Branch',
#   '621 - Dominion Trail',
#   '622 - Farmwell Station',
#   '623 - Weller',
#   '625 - Mill Run',
#   '626 - Ashby Ponds',
#   '627 - Ashbrook',
#   '628 - Moorefield Station',
#   '629 - Discovery',
#   '701 - Sully',
#   '702 - Park View',
#   '703 - Rolling Ridge',
#   '705 - Forest Grove',
#   '707 - Claude Moore Park',
#   '708 - Seneca',
#   '709 - Mirror Ridge',
#   '710 - Sterling',
#   '808 - Stone Bridge',
#   '810 - Cedar Lane',
#   '813 - Seldens Landing',
#   '814 - Newton - Lee',
#   '815 - Belmont Ridge',
#   '817 - Sanders Corner',
#   '818 - Broad Run',
#   '819 - Heritage Church',
#   '820 - Belmont Station',
#   '822 - Riverside',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Louisa County': ['101 - Zion',
#   '102 - Mechanicsville',
#   '201 - Louisa #1',
#   '202 - Louisa #2',
#   '301 - Patrick Henry No 1',
#   '302 - Patrick Henry #2',
#   '401 - Mineral',
#   '402 - Yanceyville',
#   '501 - Fredericks Hall',
#   '502 - Cuckoo',
#   '503 - Elk Creek',
#   '601 - Bumpass',
#   '602 - Locust Creek',
#   '701 - Sheltons Mill',
#   '702 - South Anna',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Lunenburg County': ['101 - Plymouth',
#   '201 - Browns Store',
#   '301 - Rosebud',
#   '302 - Flat Rock',
#   '401 - Arrowhead Gun Club',
#   '402 - Pleasant Grove',
#   '501 - Reedy Creek',
#   '502 - Peoples Community Center',
#   '601 - Hounds Creek',
#   '701 - Meherrin Fire Department',
#   '702 - Victoria Public Library',
#   'Ab - Central Absentee Precinct'],
#  'Lynchburg City': ['101 - First Ward First Precinct',
#   '102 - First Ward Second Precinct',
#   '103 - First Ward Third Precinct',
#   '104 - First Ward Fourth Precinct',
#   '105 - First Ward Fifth Precinct',
#   '201 - Second Ward First Precinct',
#   '202 - Second Ward Second Precinct',
#   '203 - Second Ward Third Precinct',
#   '204 - Second Ward Fourth Precinct',
#   '301 - Third Ward First Precinct',
#   '302 - Third Ward Second Precinct',
#   '303 - Third Ward Third Precinct',
#   '304 - Third Ward Fourth Precinct',
#   '305 - Third Ward Fifth Precinct',
#   '401 - Fourth Ward First Precinct',
#   '402 - Fourth Ward Second Precinct',
#   '403 - Fourth Ward Third Precinct',
#   '404 - Fourth Ward Fourth Precinct',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Madison County': ['1 - Oak Park',
#   '2 - Radiant',
#   '3 - Rochelle',
#   '4 - Graves Mill',
#   '5 - Madison',
#   '6 - Wolftown',
#   '7 - Brightwood',
#   '8 - Criglersville',
#   '9 - Etlan',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Manassas City': ['1 - Dean',
#   '2 - Weems',
#   '3 - Metz',
#   '4 - Haydon',
#   '5 - Baldwin',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Manassas Park City': ['1 - Precinct One',
#   '2 - Precinct Two',
#   '3 - Precinct Three',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Martinsville City': ['1 - Precinct #1',
#   '2 - Precinct #2',
#   '3 - Precinct #3',
#   '4 - Precinct #4',
#   '5 - Precinct #5',
#   '6 - Precinct #6',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Mathews County': ['1 - Chesapeake',
#   '2 - Westville',
#   '3 - Piankatank',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Mecklenburg County': ['101 - Wrights Store',
#   '102 - Pearsons Store',
#   '103 - South Clarksville',
#   '201 - Boydton',
#   '202 - Bluestone Senior High School',
#   '203 - Chase City Vfw Post',
#   '301 - Bracey',
#   '302 - Lacrosse',
#   '401 - American Legion Hall',
#   '402 - Park View Middle School',
#   '501 - South Hill',
#   '601 - Baskerville',
#   '602 - Union Level',
#   '603 - Smith Crossroads',
#   '604 - Lake Gaston',
#   '701 - Chase City',
#   '702 - Sunshine',
#   '801 - Finchley',
#   '802 - Bluestone',
#   '803 - Chase City Elementary School',
#   '901 - Averett',
#   '902 - Buffalo Springs',
#   '903 - Clarksville',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Middlesex County': ['101 - Saluda',
#   '102 - Urbanna',
#   '201 - New Market',
#   '302 - Church View',
#   '401- Harmony Village',
#   '501 - Wilton',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Montgomery County': ['101 - Precinct A-1',
#   '102 - Precinct A-2',
#   '103 - Precinct A-3',
#   '201 - Precinct B-1',
#   '202 - Precinct B-2',
#   '203 - Precinct B-3',
#   '204 - Precinct B-4',
#   '301 - Precinct C-1',
#   '302 - Precinct C-2',
#   '303 - Precinct C-3',
#   '304 - Precinct C-4',
#   '401 - Precinct D-1',
#   '402 - Precinct D-2',
#   '403 - Precinct D-3',
#   '404 - Precinct D-4',
#   '405 - Precinct D-5',
#   '501 - Precinct E-1',
#   '502 - Precinct E-2',
#   '503 - Precinct E-3',
#   '601 - Precinct F-1',
#   '602 - Precinct F-2',
#   '603 - Precinct F-3',
#   '701 - Precinct G-1',
#   '702 - Precinct G-2',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Nelson County': ['101 - Rockfish',
#   '201 - Lovingston',
#   '202 - Schuyler',
#   '301 - Shipman',
#   '302 - Gladstone',
#   '401 - Roseland',
#   '402 - Montebello',
#   '501 - Faber',
#   '502 - Nellysford',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'New Kent County': ['102 - Tunstall',
#   '103 - Southern Branch',
#   '201 - Quinton',
#   '202 - Kentwood',
#   '301 - Watkins',
#   '302 - Cumberland',
#   '401 - Providence Forge',
#   '403 - Mountcastle',
#   '501 - Eltham',
#   '502 - Chickahominy River',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Newport News City': ['101 - Denbigh (CD 3)',
#   '102 - Epes (CD 3)',
#   '103 - Jenkins (CD 3)',
#   '104 - Mcintosh (CD 3)',
#   '105 - Oyster Point (CD 3)',
#   '106 - Reservoir (CD 3)',
#   '107 - Richneck (CD 3)',
#   '108 - Lee Hall (CD 3)',
#   '109 - Windsor (CD 3)',
#   '110 - Greenwood (CD 3)',
#   '201 - Bland (CD 3)',
#   '202 - Boulevard (CD 3)',
#   '203 - Charles (CD 3)',
#   '204 - Wellesley (CD 3)',
#   '205 - Deep Creek (CD 3)',
#   '208 - Hidenwood (CD 3)',
#   '209 - Hilton (CD 3)',
#   '210 - Nelson (CD 3)',
#   '211 - Palmer (CD 3)',
#   '212 - Riverside (CD 3)',
#   '213 - Sanford (CD 3)',
#   '215 - Warwick (CD 3)',
#   '216 - Yates (CD 3)',
#   '217 - Riverview (CD 3)',
#   '218 - Kiln Creek (CD 3)',
#   '219 - Deer Park (CD 3)',
#   '302 - Briarfield (CD 3)',
#   '303 - Carver (CD 3)',
#   '304 - Chestnut (CD 3)',
#   '305 - Downtown (CD 3)',
#   '306 - Dunbar (CD 3)',
#   '307 - Huntington (CD 3)',
#   '308 - Jefferson (CD 3)',
#   '309 - Magruder (CD 3)',
#   '310 - Marshall (CD 3)',
#   '311 - Newmarket (CD 3)',
#   '312 - Newsome Park (CD 3)',
#   '313 - Reed (CD 3)',
#   '314 - River (CD 3)',
#   '315 - Sedgefield (CD 3)',
#   '316 - South Morrison (CD 3)',
#   '317 - Washington (CD 3)',
#   '318 - Wilson (CD 3)',
#   '319 - Saunders (CD 3)',
#   '320 - Watkins (CD 3)',
#   'Ab - Central Absentee Precinct (CD 3)',
#   'Provisional (CD 3)'],
#  'Norfolk City': ['101 - Granby (CD 2)',
#   '101 - Granby (CD 3)',
#   '102 - Ocean View School (CD 2)',
#   '103 - Northside (CD 2)',
#   '104 - Titustown (CD 2)',
#   '104 - Titustown (CD 3)',
#   '106 - Zion Grace (CD 2)',
#   '201 - Old Dominion (CD 3)',
#   '203 - Ghent Square (CD 3)',
#   "207 - Lambert's Point (CD 3)",
#   '208 - Larchmont Library (CD 3)',
#   '210 - Maury (CD 3)',
#   '211 - Chrysler Museum (CD 3)',
#   '212 - Park Place (CD 3)',
#   '213 - Taylor Elementary School (CD 3)',
#   '214 - Stuart (CD 3)',
#   '215 - Suburban Park (CD 2)',
#   '217 - Wesley (CD 2)',
#   '218 - Willard (CD 3)',
#   '301 - Ballentine (CD 3)',
#   '302 - Tanners Creek (CD 3)',
#   '303 - Bowling Park (CD 3)',
#   '304 - Coleman Place School (CD 3)',
#   '305 - Lafayette-winona (CD 3)',
#   '306 - Lindenwood (CD 3)',
#   '309 - Norview (CD 3)',
#   '310 - Rosemont (CD 3)',
#   '311 - Sherwood (CD 3)',
#   '313 - Union Chapel (CD 3)',
#   '402 - Berkley (CD 3)',
#   '403 - Brambleton (CD 3)',
#   '404 - Campostella (CD 3)',
#   '405 - Chesterfield (CD 3)',
#   '406 - Barron Black (CD 2)',
#   '408 - Easton (CD 3)',
#   '409 - Fairlawn (CD 3)',
#   '411 - Ruffner Academy (CD 3)',
#   '412 - Ingleside (CD 3)',
#   '413 - Poplar Halls (CD 3)',
#   '414 - Young Park (CD 3)',
#   '415 - Lake Taylor High School (CD 3)',
#   '501 - Bayview (CD 2)',
#   '503 - East Ocean View (CD 2)',
#   '504 - Larrymore (CD 2)',
#   '505 - Little Creek (CD 2)',
#   '506 - Ocean View Center (CD 2)',
#   '507 - Pretlow (CD 2)',
#   '509 - Tarrallton (CD 2)',
#   '510 - Third Presbyterian (CD 2)',
#   '511 - Crossroads (CD 2)',
#   '512 - Azalea Gardens (CD 2)',
#   'Ab - Central Absentee Precinct (CD 2)',
#   'Ab - Central Absentee Precinct (CD 3)',
#   'Provisional (CD 2)',
#   'Provisional (CD 3)'],
#  'Northampton County': ['101 - Precinct 1-1',
#   '201 - Precinct 2-1',
#   '301 - Precinct 3-1',
#   '401 - Precinct 4-1',
#   '501 - Precinct 5-1',
#   'Ab - Central Absentee Precinct'],
#  'Northumberland County': ['101 - 1a',
#   '201 - 2a',
#   '301 - 3a',
#   '302 - 3b',
#   '401 - 4a',
#   '501 - 5a',
#   'Ab - Central Absentee Precinct'],
#  'Norton City': ['1 - East Ward'],
#  'Nottoway County': ['101 - Precinct 1-1',
#   '102 - Precinct 1-2',
#   '201 - Precinct 2-1',
#   '202 - Precinct 2-2',
#   '301 - Precinct 3-1',
# ...
#   '105 - One Hundred Five (CD 4)',
#   '106 - One Hundred Six (CD 4)',
#   '111 - One Hundred Eleven (CD 4)',
#   '112 - One Hundred Twelve (CD 4)',
#   '113 - One Hundred Thirteen (CD 4)',
#   '114 - One Hundred Fourteen (CD 4)',
#   '203 - Two Hundred Three (CD 4)',
#   '204 - Two Hundred Four (CD 4)',
#   '206 - Two Hundred Six (CD 4)',
#   '207 - Two Hundred Seven (CD 4)',
#   '208 - Two Hundred Eight (CD 4)',
#   '213 - Two Hundred Thirteen (CD 4)',
#   '301 - Three Hundred One (CD 4)',
#   '302 - Three Hundred Two (CD 4)',
#   '303 - Three Hundred Three (CD 4)',
#   '304 - Three Hundred Four (CD 4)',
#   '305 - Three Hundred Five (CD 4)',
#   '306 - Three Hundred Six (CD 4)',
#   '307 - Three Hundred Seven (CD 4)',
#   '308 - Three Hundred Eight (CD 4)',
#   '309 - Three Hundred Nine (CD 4)',
#   '310 - Three Hundred Ten (CD 4)',
#   '402 - Four Hundred Two (CD 4)',
#   '404 - Four Hundred Four (CD 4)',
#   '409 - Four Hundred Nine (CD 4)',
#   '410 - Four Hundred Ten (CD 4)',
#   '412 - Four Hundred Twelve (CD 4)',
#   '413 - Four Hundred Thirteen (CD 4)',
#   '414 - Four Hundred Fourteen (CD 4)',
#   '501 - Five Hundred One (CD 4)',
#   '503 - Five Hundred Three (CD 4)',
#   '504 - Five Hundred Four (CD 4)',
#   '505 - Five Hundred Five (CD 4)',
#   '508 - Five Hundred Eight (CD 4)',
#   '509 - Five Hundred Nine (CD 4)',
#   '510 - Five Hundred Ten (CD 4)',
#   '602 - Six Hundred Two (CD 4)',
#   '603 - Six Hundred Three (CD 4)',
#   '604 - Six Hundred Four (CD 4)',
#   '606 - Six Hundred Six (CD 4)',
#   '607 - Six Hundred Seven (CD 4)',
#   '609 - Six Hundred Nine (CD 4)',
#   '610 - Six Hundred Ten (CD 4)',
#   '701 - Seven Hundred One (CD 4)',
#   '702 - Seven Hundred Two (CD 4)',
#   '703 - Seven Hundred Three (CD 4)',
#   '705 - Seven Hundred Five (CD 4)',
#   '706 - Seven Hundred Six (CD 4)',
#   '707 - Seven Hundred Seven (CD 4)',
#   '708 - Seven Hundred Eight (CD 4)',
#   '802 - Eight Hundred Two (CD 4)',
#   '806 - Eight Hundred Six (CD 4)',
#   '810 - Eight Hundred Ten (CD 4)',
#   '811 - Eight Hundred Eleven (CD 4)',
#   '812 - Eight Hundred Twelve (CD 4)',
#   '814 - Eight Hundred Fourteen (CD 4)',
#   '902 - Nine Hundred Two (CD 4)',
#   '903 - Nine Hundred Three (CD 4)',
#   '908 - Nine Hundred Eight (CD 4)',
#   '909 - Nine Hundred Nine (CD 4)',
#   '910 - Nine Hundred Ten (CD 4)',
#   '911 - Nine Hundred Eleven (CD 4)',
#   'AB - Central Absentee Precinct (CD 4)',
#   'Provisional (CD 4)'],
#  'Roanoke County': ['101 - Catawba (CD 9)',
#   '102 - Mason Valley (CD 9)',
#   '103 - Glenvar (CD 9)',
#   '104 - Northside (CD 9)',
#   '105 - Peters Creek (CD 9)',
#   '106 - Green Hill (CD 9)',
#   '107 - Bennett Springs (CD 9)',
#   '108 - Wildwood (CD 9)',
#   '201 - Plantation (CD 6)',
#   '202 - Burlington (CD 6)',
#   '203 - Mountain View (CD 6)',
#   '204 - Botetourt Springs (CD 9)',
#   '205 - Orchards (CD 6)',
#   '206 - Hollins (CD 6)',
#   '301 - Bent Mountain (CD 9)',
#   '302 - Poages Mill (CD 6)',
#   '303 - Windsor Hills (CD 6)',
#   '304 - Oak Grove (CD 6)',
#   '305 - Castle Rock (CD 6)',
#   '306 - Garst Mill (CD 6)',
#   '402 - Bonsack (CD 6)',
#   '403 - North Vinton (CD 6)',
#   '404 - South Vinton (CD 6)',
#   '405 - Lindenwood (CD 6)',
#   '406 - Mount Pleasant (CD 6)',
#   '501 - Cotton Hill (CD 6)',
#   '502 - Penn Forest (CD 6)',
#   '503 - Cave Spring (CD 6)',
#   '504 - Ogden (CD 6)',
#   '505 - Clearbrook (CD 6)',
#   '506 - Mount Vernon (CD 6)',
#   '507 - Hunting Hills (CD 6)',
#   'Ab - Central Absentee Precinct (CD 6)',
#   'Ab - Central Absentee Precinct (CD 9)',
#   'Provisional (CD 6)',
#   'Provisional (CD 9)'],
#  'Roanoke City': ['1 -Peters Creek',
#   '2 - Grandview',
#   '3 -Preston Park',
#   '4 - Williamson Road',
#   '5 - East Gate',
#   '6 - Hollins Road',
#   '7 - Southeast',
#   '8 - Lincoln Terrace',
#   '9 - Highland',
#   '10 - Old Southwest-Wasena',
#   '11 - Raleigh Court',
#   '12 - South Roanoke',
#   '13 - Garden City',
#   '14 - Crystal Spring',
#   '15 - Grandin Court',
#   '16 - Deyerle',
#   '17 - Lee-Hi',
#   '18 - Virginia Heights-Norwich',
#   '19 - Summit Hills',
#   '20 - Forest Park',
#   '21 - Eureka Park',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Rockbridge County': ['101 - Airport',
#   '102 - Ben Salem',
#   '103 - Plank Road',
#   '104 - Effinger',
#   '201 - Collierstown',
#   '202 - Highland Belle',
#   '203 - Vo-tech',
#   '301 - Maury River',
#   '302 - Natural Bridge',
#   '303 - Falling Spring',
#   '401 - Fairfield',
#   '402 - Mountain View',
#   '403 - Vesuvius',
#   '501 - Goshen',
#   '502 - Meadowview',
#   '503 - Rockbridge Baths',
#   '504 - Rockbridge',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Rockingham County': ['101 - Broadway',
#   '102 - Timberville',
#   '103 - Fulks Run',
#   '104 - Bergton',
#   '105 - Lacey Spring',
#   '106 - Tenth Legion',
#   '107 - Plains',
#   '108 - Little North Mountain',
#   '201 - Singers Glen',
#   '202 - Edom',
#   '203 - Dayton',
#   '204 - Mt Clinton',
#   '205 - Silver Lake',
#   '301 - Keezletown',
#   '302 - Port Republic',
#   '303 - Melrose',
#   '304 - Grottoes',
#   '305 - Massanetta Springs',
#   '306 - Cross Keys',
#   '307 - Crossroads',
#   '401 - Bridgewater',
#   '402 - Montezuma',
#   '403 - Mt Crawford',
#   '404 - North River',
#   '405 - Ottobine',
#   '501 - Elkton',
#   '502 - Swift Run',
#   '503 - Mcgaheysville',
#   '504 - South Fork',
#   '505 - Stony Run',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Russell County': ['101 - Moccasin',
#   '102 - Copper Creek',
#   '103 - South Castlewood',
#   '201 - North Castlewood',
#   '202 - Dante',
#   '301 - Cooks Mill',
#   '302 - Daugherty',
#   '303 - New Garden',
#   '304 - Cleveland',
#   '401 - Drill',
#   '402 - Swords Creek',
#   '403 - Honaker',
#   '501 - West Lebanon',
#   '601 - East Lebanon',
#   '602 - Elk Garden',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Salem City': ['1 - North Salem No 2',
#   '2 - Conehurst',
#   '3 - Beverly Heights',
#   '4 - West Salem',
#   '5 - North Salem No 1',
#   '6 - South Salem No 1',
#   '7 - South Salem No 2',
#   '8 - East Salem',
#   '9 - South Side Hills',
#   '10 - Hidden Valley',
#   'Ab - Central Absentee Precinct'],
#  'Scott County': ['101 - Weber City',
#   '102 - Yuma',
#   '202 - Weber City East',
#   '203 - Hiltons',
#   "204 - Clark's",
#   '301 - Nickelsville',
#   '302 - Snowflake',
#   '303 - Twin Springs',
#   '304 - Copper Creek',
#   '401 - Gate City',
#   '501 - Dungannon',
#   '502 - Fort Blackmore',
#   '503 - Manville',
#   '504 - Rye Cove',
#   '601 - Clinchport',
#   '602 - Duffield-pattonsville',
#   '603 - Fairview',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Shenandoah County': ['101 - Orkney Springs',
#   '103 - New Market',
#   '201 - Conicville',
#   '202 - Mt Jackson',
#   '302 - Edinburg',
#   '303 - St Luke',
#   '304 - Fort Valley',
#   '401 - Woodstock',
#   '501 - Cedar Creek',
#   '503 - Toms Brook',
#   '504 - Lebanon Church',
#   '601 - Strasburg',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Smyth County': ['101 - Saltville',
#   '201 - Seven Mile Ford',
#   '202 - Rich Valley',
#   '301 - Chilhowie',
#   '302 - St Clair',
#   '401 - East Park',
#   '402 - West Park',
#   '501 - Atkins',
#   '502 - Wassona',
#   '601 - Royal Oak East',
#   '602 - Royal Oak West',
#   '701 - Adwolfe',
#   '702 - Sugar Grove',
#   '703 - Konnarock',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Southampton County': ['101 - Berlin',
#   '102 - Ivor',
#   '201 - Boykins',
#   '202 - Branchville',
#   '301 - Capron',
#   '302 - Sebrell',
#   '401 - Drewryville',
#   '501 - Hunterdale',
#   '502 - Forks-of-the-river',
#   '601 - Courtland',
#   '602 - Sedley',
#   '701 - Blackwater River',
#   '702 - Newsoms',
#   'Ab - Central Absentee Precinct'],
#  'Spotsylvania County': ['101 - Partlow (CD 7)',
#   '102 - Blaydes Corner (CD 7)',
#   '103 - Travelers Rest (CD 1)',
#   '103 - Travelers Rest (CD 7)',
#   '104 - Massaponax (CD 1)',
#   '201 - Wilderness School (CD 7)',
#   '202 - Wilderness Fire (CD 7)',
#   '203 - Ni River / Elys Ford (CD 7)',
#   '204 - Chancellor (CD 7)',
#   '301 - Plank Road (CD 7)',
#   '302 - Hazel Run (CD 7)',
#   '303 - Riverbend (CD 7)',
#   '401 - Summit (CD 1)',
#   '402 - Parkside (CD 1)',
#   '402 - Parkside (CD 7)',
#   '403 - Lee Hill (CD 1)',
#   '501 - Belmont (CD 7)',
#   '502 - Brokenburg (CD 7)',
#   '503 - Post Oak (CD 7)',
#   '504 - Courthouse (CD 7)',
#   '505 - Brock (CD 7)',
#   '601 - Salem (CD 7)',
#   '602 - Smith Station (CD 7)',
#   '603 - Piedmont (CD 7)',
#   '701 - Battlefield (CD 1)',
#   '702 - Brents Mill (CD 1)',
#   '702 - Brents Mill (CD 7)',
#   '703 - Fairview (CD 1)',
#   '703 - Fairview (CD 7)',
#   '704 - Gayle (CD 1)',
#   '704 - Gayle (CD 7)',
#   'Ab - Central Absentee Precinct (CD 1)',
#   'Ab - Central Absentee Precinct (CD 7)',
#   'Provisional (CD 1)',
#   'Provisional (CD 7)'],
#  'Stafford County': ['101 - Hartwood',
#   '102 - Rocky Run',
#   '103 - Simpson',
#   '104 - College',
#   '201 - Rock Hill',
#   '202 - Roseville',
#   '203 - Ruby',
#   '204 - Stefaniga',
#   '301 - Griffis',
#   '302 - Widewater',
#   '303 - Harbour',
#   '304 - Barrett',
#   '401 - Aquia',
#   '402 - Courthouse',
#   '403 - Brooke',
#   '404 - Government Island',
#   '501 - Grafton',
#   '502 - Falmouth',
#   '503 - Drew',
#   '504 - Gayle',
#   '601 - Ferry Farm',
#   '602 - Chatham',
#   '603 - White Oak',
#   '604 - England Run',
#   '701 - Woodlands',
#   '702 - Whitson',
#   '703 - Hampton',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Staunton City': ['101 - Ward No 1',
#   '201 - Ward Two',
#   '301 - Ward No 3',
#   '401 - Ward No 4',
#   '501 - Ward No 5',
#   'Ab - Central Absentee Precinct'],
#  'Suffolk City': ['101 - Belleharbour (CD 3)',
#   '102 - Driver (CD 3)',
#   '104 - Bennetts Creek (CD 3)',
#   '201 - Ebenezer (CD 3)',
#   '202 - Chuckatuck (CD 3)',
#   '203 - Kings Fork (CD 3)',
#   '204 - Hillpoint (CD 3)',
#   '301 - White Marsh (CD 4)',
#   '302 - John F Kennedy (CD 3)',
#   '302 - John F Kennedy (CD 4)',
#   '304 - Nansemond River (CD 3)',
#   '305 - Shoulders Hill (CD 3)',
#   '401 - Airport (CD 4)',
#   '402 - Whaleyville (CD 4)',
#   '403 - Southside (CD 4)',
#   '404 - Booker T Washington (CD 3)',
#   '404 - Booker T Washington (CD 4)',
#   '405 - Pittmantown (CD 4)',
#   '501 - Kilbys Mill (CD 4)',
#   '502 - Holland (CD 4)',
#   '504 - Lake Cohoon (CD 3)',
#   '504 - Lake Cohoon (CD 4)',
#   '601 - Lakeside (CD 4)',
#   '602 - Olde Towne (CD 3)',
#   '602 - Olde Towne (CD 4)',
#   '603 - Elephants Fork/westhaven (CD 4)',
#   '604 - Wilroy (CD 3)',
#   '605 - Hollywood (CD 3)',
#   '702 - Harbourview (CD 3)',
#   '704 - Burbage Grant (CD 3)',
#   '706 - Huntersville (CD 3)',
#   'AB - Central Absentee Precinct (CD 3)',
#   'Ab - Central Absentee Precinct (CD 4)',
#   'Provisional (CD 3)',
#   'Provisional (CD 4)'],
#  'Surry County': ['101 - Surry',
#   '201 - Bacons Castle',
#   '301 - Dendron',
#   '302 - Walls Bridge',
#   '401 - Carsley',
#   '501 - Claremont',
#   '502 - Spring Grove',
#   'Provisional'],
#  'Sussex County': ['101 - Waverly',
#   '201 - Stony Creek',
#   '202 - Little Mill',
#   '301 - Courthouse',
#   '302 - Wakefield',
#   '401 - Mars Hill',
#   '402 - West Wakefield',
#   '501 - Henry',
#   '502 - Yale',
#   '601 - Blackwater',
#   '602 - Newville',
#   'AB - Central Absentee Precinct',
#   'Provisional'],
#  'Tazewell County': ['101 - Abbs Valley',
#   '102 - Tip Top',
#   '103 - Boissevain',
#   '104 - Falls Mills',
#   '106 - Pocahontas',
#   '107 - Amonate',
#   '109 - Bishop',
#   '110 - Adria',
#   '111 - Gap Store',
#   '112 - Bandy',
#   '203 - Burkes Garden',
#   '204 - Clear Fork',
#   '207 - Freestone',
#   '209 - Jeffersonville',
#   '214 - Thompson Valley',
#   '301 - Cedar Bluff',
#   '302 - Baptist Valley',
#   '303 - Wardell',
#   '305 - Pounding Mill',
#   '401 - Richlands',
#   '402 - Jewell Ridge',
#   '404 - Raven',
#   '501 - Springville',
#   '502 - Graham',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Virginia Beach City': ['1 - North Beach',
#   '2 - South Beach',
#   '3 - Ocean Lakes',
#   '4 - Linkhorn',
#   '5 - Seatack',
#   '6 - Alanton',
#   '7 - Kingston',
#   '8 - London Bridge',
#   '9 - Trantwood',
#   '10 - Great Neck',
#   '11 - Cape Henry',
#   '12 - Plaza',
#   '13 - Mt Trashmore',
#   '14 - Malibu',
#   '15 - Old Donation',
#   '16 - Aragona',
#   '17 - Ocean Park',
#   '18 - Thoroughgood',
#   '19 - Lake Smith',
#   '20 - Bayside',
#   '21 - Davis Corner',
#   '22 - Point O View',
#   '23 - Arrowhead',
#   '24 - Larkspur',
#   '25 - Avalon',
#   '26 - Fairfield',
#   '27 - Edwin',
#   '28 - Thalia',
#   '29 - Holland',
#   '30 - Red Wing',
#   '31 - Sigma',
#   '32 - Creeds',
#   '33 - Capps Shop',
#   '34 - Blackwater',
#   '35 - Courthouse',
#   '36 - Windsor Oaks',
#   '37 - Chesapeake Beach',
#   '38 - Witchduck',
#   '39 - Pembroke',
#   '40 - Bonney',
#   '41 - College Park',
#   '42 - Brandon',
#   '43 - Bellamy',
#   '44 - Centerville',
#   '45 - Timberlake',
#   '46 - Green Run',
#   '47 - Kings Grant',
#   '48 - Wolfsnare',
#   '49 - Lynnhaven',
#   '50 - Oceana',
#   '51 - Stratford Chase',
#   '52 - Homestead',
#   '53 - Shannon',
#   '54 - Cromwell',
#   '55 - Magic Hollow',
#   '56 - Edinburgh',
#   '57 - Sherry Park',
#   '58 - Glenwood',
#   '59 - Shelton Park',
#   '60 - Foxfire',
#   '61 - Baker',
#   '62 - Landstown',
#   '63 - Culver',
#   '64 - Rosemont Forest',
#   '65 - Colonial',
#   '66 - Hunt',
#   '67 - Eastern Shore',
#   '68 - Manor',
#   '69 - Shell',
#   '70 - Corporate Landing',
#   '71 - Round Hill',
#   '72 - Rudee',
#   '73 - Dahlia',
#   '74 - Buckner',
#   '75 - Colony',
#   '76 - Village',
#   '77 - Brookwood',
#   '78 - Indian Lakes',
#   '79 - Pleasant Hall',
#   '80 - Chimney Hill',
#   '81 - Rock Lake',
#   '82 - Shelburne',
#   '83 - Strawbridge',
#   '84 - Tallwood',
#   '85 - Upton',
#   '86 - Haygood',
#   '87 - Hillcrest',
#   '88 - North Landing',
#   '89 - Lake Christopher',
#   '90 - Lake Joyce',
#   '91 - Lexington',
#   '92 - Little Neck',
#   '93 - Newtown',
#   '94 - Pinewood',
#   '95 - Dam Neck',
#   '96 - Hilltop',
#   '97 - Indian River',
#   '98 - Independence',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Warren County': ['101 - Fork Town',
#   '102 - Otterburn',
#   '201 - Happy Creek',
#   '202 - Linden',
#   '301 - North River',
#   '302 - Riverton',
#   '401 - East Shenandoah',
#   '402 - Town - West Shenandoah',
#   '501 - South River',
#   '502 - Bentonville',
#   '504 - Browntown',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Washington County': ['101 - East Abingdon',
#   '102 - West Abingdon',
#   '201 - Clinchburg',
#   '202 - Greendale',
#   '203 - Hayters Gap',
#   '204 Woodland Hills',
#   '301 - Watauga',
#   '302 - South Abingdon',
#   '401 - Glade Spring',
#   '402 - Meadowview',
#   '501 - Rhea Valley',
#   '502 - Damascus',
#   '504 - Green Cove',
#   '601 - Burson Place',
#   '602 - Mendota',
#   '603 - Valley Institute',
#   '701 - High Point',
#   '702 - Wallace',
#   '703 - John Battle',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Waynesboro City': ['1 - Ward A',
#   '2 - Ward B',
#   '3 - Ward C',
#   '4 - Ward D',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Westmoreland County': ['101 - Precinct 1-1',
#   '102 - Precinct 1-2',
#   '201 - Precinct 2-1',
#   '202 - Precinct 2-2',
#   '301 - Precinct 3-1',
#   '302 - Precinct 3-2',
#   '401 - Precinct 4-1',
#   '501 - Precinct 5-1',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Williamsburg City': ['1 - Stryker',
#   '2 - Matoaka',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Winchester City': ['101 - Merrimans',
#   '102 - Old Town',
#   '201 - Virginia Avenue',
#   '301 - War Memorial',
#   '401 - Frederick Douglass',
#   '402 - Rolling Hills',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Wise County': ['101 - Appalachia',
#   '102 - Dorchester',
#   '103 - Guest River Voting Place',
#   '104 - West Pound',
#   '201 - North Coeburn',
#   '202 - Wise',
#   '203 - East Pound',
#   '301 - Big Stone Gap',
#   '302 - East Stone Gap',
#   '401 - Clinch Valley',
#   '402 - South Coeburn',
#   '403 - St Paul',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'Wythe County': ['101 - Royal Oak',
#   '102 - Rural Retreat',
#   '203 - West Wytheville',
#   '303 - East Wytheville',
#   '401 - Fort Chiswell',
#   '402 - Max Meadows',
#   '501 - Jackson Memorial',
#   '502 - Sheffey',
#   '601 - Huddle',
#   '602 - Zion',
#   '603 Evergreen',
#   'Ab - Central Absentee Precinct',
#   'Provisional'],
#  'York County': ['101 - Queens Lake',
#   '102 - Waller Mill',
#   '103 - Magruder',
#   '201 - Coventry',
#   '202 - Kiln Creek',
#   '301 - Seaford',
#   '302 - Yorktown',
#   '303 - Edgehill',
#   '401 - Harwoods Mill',
#   '402 - Dare',
#   '403 - Grafton',
#   '501 - Tabb',
#   '502 - Bethel',
#   'Ab - Central Absentee Precinct',
#   'Provisional']}

# %%
# Check that find_sprob in Providence is working as expected
from r2b2.minerva2 import Minerva2
from r2b2.contest import Contest
from r2b2.contest import ContestType

# Get contest
contest_name = 'Virginia 2016 presidential contest'
tally = {'Hillary R. Clinton': 1981473, 'Donald J. Trump': 1769443, 'Gary Johnson': 118274, 'Evan McMullin':54054, 'Jill Stein':27638, 'All Others':33749}
reported_winner = max(tally, key=tally.get)
winner_votes = tally[reported_winner]
total_relevant = sum(tally.values())
loser_votes = total_relevant - winner_votes
margin = (winner_votes / total_relevant) - (loser_votes / total_relevant)
contest = Contest(total_relevant,
                            tally,
                            num_winners=1,
                            reported_winners=[reported_winner],
                            contest_type=ContestType.PLURALITY)

# Create audit
M = Minerva2(.1, 1.0, contest)

# Execute a round of the audit for this sample
sample = {'Hillary R. Clinton': 100, 'Donald J. Trump': 100, 'Gary Johnson': 4, 'Evan McMullin':3, 'Jill Stein':1, 'All Others':1}
stop = M.execute_round(sum(sample.values()), sample)
print(stop)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [81], line 2
#       1 # Check that find_sprob in Providence is working as expected
# ----> 2 from r2b2.minerva2 import Minerva2
#       3 from r2b2.contest import Contest
#       4 from r2b2.contest import ContestType
#
# ModuleNotFoundError: No module named 'r2b2'
